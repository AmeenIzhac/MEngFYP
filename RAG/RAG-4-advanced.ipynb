# %%
OPENAI_API_KEY = "INSERT_OPEN_API_KEY_HERE"
ANTHROPIC_API_KEY = "INSERT_ANTHROPIC_API_KEY_HERE"

# %%
from llama_index.core import VectorStoreIndex, get_response_synthesizer
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.selectors import LLMSingleSelector
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import StorageContext, load_index_from_storage
import nest_asyncio
nest_asyncio.apply()

# %%
documents = SimpleDirectoryReader(input_files=["anatomybook.pdf"]).load_data()
nodes = SentenceSplitter(chunk_size=128, chunk_overlap=25).get_nodes_from_documents(documents)

# %%
Settings.llm = OpenAI(model="gpt-3.5-turbo", api_key=OPENAI_API_KEY)
Settings.embed_model = OpenAIEmbedding(model="text-embedding-ada-002", api_key=OPENAI_API_KEY)

# %%
index = VectorStoreIndex(nodes)

# %%
from llama_index.core.retrievers import QueryFusionRetriever

query_engine1 = index.as_query_engine(similarity_top_k=2)

vector_retriever = index.as_retriever(similarity_top_k=2)

next_retreiver = QueryFusionRetriever(
    [vector_retriever],
    similarity_top_k=2,
    num_queries=4,  # set this to 1 to disable query generation
    mode="reciprocal_rerank",
    use_async=True,
    verbose=True,
    # query_gen_prompt="...",  # we could override the query generation prompt here
)

# query_engine2 = RetrieverQueryEngine(
#     retriever = next_retreiver,
#     response_synthesizer=get_response_synthesizer(),
#     node_postprocessors=[SimilarityPostprocessor(similarity_cutoff=0.7)],
# )

from llama_index.core.query_engine import RetrieverQueryEngine

query_engine2 = RetrieverQueryEngine.from_args(next_retreiver)

# %%
from datasets import load_dataset

dataset_validation = load_dataset("openlifescienceai/medmcqa", split="validation").filter(lambda example: example["subject_name"] == "Anatomy")

# %% [markdown]
# # query engine 1

# %%
# Out:
# [NodeWithScore(node=TextNode(id_='e01448b8-a435-425e-aea5-91e2285389af', embedding=None, metadata={'page_label': '478', 'file_name': 'anatomybook.pdf', 'file_path': 'anatomybook.pdf', 'file_type': 'application/pdf', 'file_size': 52581393, 'creation_date': '2024-05-27', 'last_modified_date': '2024-05-20'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='fd3715d4-c0bd-4899-bf71-d4237dc4bafa', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '478', 'file_name': 'anatomybook.pdf', 'file_path': 'anatomybook.pdf', 'file_type': 'application/pdf', 'file_size': 52581393, 'creation_date': '2024-05-27', 'last_modified_date': '2024-05-20'}, hash='722159b8a4f8ce8fab16792e14f41bb31dc3b78b5ec1e1ea64629801a6c94d91')}, text='This page intentionally left blank', start_char_idx=0, end_char_idx=34, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.7623143666803067),
#  NodeWithScore(node=TextNode(id_='5c367824-de2f-4d7a-83e4-6b810e3abe62', embedding=None, metadata={'page_label': '12', 'file_name': 'anatomybook.pdf', 'file_path': 'anatomybook.pdf', 'file_type': 'application/pdf', 'file_size': 52581393, 'creation_date': '2024-05-27', 'last_modified_date': '2024-05-20'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ae4780bf-ec71-428d-b6cc-d942a9a68f76', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '12', 'file_name': 'anatomybook.pdf', 'file_path': 'anatomybook.pdf', 'file_type': 'application/pdf', 'file_size': 52581393, 'creation_date': '2024-05-27', 'last_modified_date': '2024-05-20'}, hash='e25498548c943145c5f52759e54d8efbd251108ec1e50b4c93a0ec216517d1e9'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='0b0135cd-f490-4797-be66-56508434e64e', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='70a5fdad30a229b4085e77dd2dc7b9bd4d7067050c42608e6d230b95e732e545')}, text='x Preface\nor allied health education.', start_char_idx=0, end_char_idx=37, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), score=0.7592255221876022)]

# %%
def predict1(prompt):
    return str(query_engine1.query(prompt))
    

def evaluate1():
  SAMPLE_CNT = len(dataset_validation)
  mismatch_cnt = 0
  predictions = []
  references = []

  for i in range(SAMPLE_CNT):
    example = dataset_validation[i]
    question, option_a, option_b, option_c, option_d = example["question"], example["opa"], example["opb"], example["opc"], example["opd"]
    prompt = f'''{question}

{option_a}
{option_b}
{option_c}
{option_d}

Respond with the correct choice from the list above verbatim.  Do not include any explanation.'''

    options = [example['opa'], example['opb'], example['opc'], example['opd']]
    reference = options[example['cop']]
    references.append(reference)

    prediction = predict1(prompt)
    if prediction not in options:
      prompt += prediction + "\n\nYour response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again\n\n" + example['opa'] + "\n\n" + example['opb'] + "\n\n" + example['opc'] + "\n\n" + example['opd']
      prediction = predict1(prompt)

    if prediction != reference:
       print(prompt)
       rets = vector_retriever.retrieve(prompt)
       print("RETRIEVAL 1", rets[0].text)
       print("RETRIEVAL 2", rets[1].text)
       print('PREDICTION:', prediction)
       print('\n\n-----------------------------------\n\n')
       

    predictions.append(prediction)

    mismatch_cnt += prediction not in options

  exact_match = sum([prediction == reference for prediction, reference, in zip(predictions, references)]) / SAMPLE_CNT
  mismatch = mismatch_cnt / SAMPLE_CNT

  return exact_match, mismatch

exact_match, mismatch = evaluate1()
# Out:
# Which of the following are not a branch of external carotid Aery in Kiesselbach's plexus.
#
# Sphenopalatine aery
# Anterior ethmoidal aery
# Greater palatine aery
# Septal branch of superior labial aery
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Maxillary a.
# Posterior auricular a.
# Facial a.
# Lingual a.
# Superior thyroid a.Ascending pharyngeal a.
# Superficial temporal a.
# Maxillary a.
# Posterior auricular a.
# Facial a.
# Lingual a.
# Ascending pharyngeal a.Occipital a.
# Superior thyroid a. and superior laryngeal branch
# FIGURE 8.51  External Carotid Artery and Branches.
# RETRIEVAL 2 other ﬁbers also may course
# via the deep petrosal nerve  (postganglionic
# sympathetic ﬁbers on the internal carotid artery),
# which joins the greater petrosal nerve to become
# Lateral wall of nasal cavity
# Greater palatine arteryLesser palatine arteryMaxillary artery
# External carotid arterySphenopalatine artery Anterior lateral nasal branch
# External nasal branch
# of anterior ethmoidal
# artery
# Nasal septal branch of superior
# labial branch (of facial
# PREDICTION: Greater palatine aery
#
#
# -----------------------------------
#
#
# Which pa of brachial plexus do not give branches
#
# Root
# Division
# Cord
# Trunk
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 7.10 ).
# he plexus is descriptively divided into ive roots
# (anterior rami), three trunks, six divisions (three
# anterior, three posterior), three cords (named for
# their relationship to the axillary artery), and ive
# large terminal branches. Important motor branches
# of the brachial plexus are described in Table 7.5 .
# RETRIEVAL 2 Which of the following
# components of her brachial plexus was most
# likely injured during the diicult delivery?
#  A. Lateral cord
#  B. Medial cord
#  C. Posterior cord
#  D. Roots of inferior trunk
#  E. Roots of middle trunk
#  F. Roots of superior trunk
# 22. During upper limb bud development, the limb
# myotomes give rise to collections of mesoderm
# that become the muscles of the shoulder, arm,
# forearm, and hand.
# PREDICTION: Root
#
#
# -----------------------------------
#
#
# The cells which will proliferate from top to bottom of villi are:
#
# Chief cells
# Goblet cells
# Paneth cells
# Parietal cells
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 A. Astrocytes
#  B. Ependymal cells
#  C. Microglia
#  D. Oligodendrocytes
#  E. Schwann cells
# Multiple-choice and short-answer review questions available online; see inside front cover for details.
# RETRIEVAL 2 Simultaneously, the inner cell mass develops into the
# following two cell types (bilaminar disc formation):
# • Epiblast:  formation of a sheet of columnar cells
# on the dorsal surface of the embryoblast.
# • Hypoblast:  a sheet of cuboidal cells on the
# ventral surface of the embryoblast.
# he epiblast forms a cavity on the dorsal side
# that gives rise to the amniotic cavity.
# PREDICTION: Goblet cells
#
#
# -----------------------------------
#
#
# Retraction of mandible is achieved by:
#
# Lateral pterygoid
# Temporalis
# Medial pterygoid
# Masseter
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Medial
# pterygoid m.
# Parotid duct
# Buccinator m.
# Pterygomandibular
# raphe
# Lateral viewArticular disc of
# temporomandibular joint
# Masseter m.Temporalis m.
# Lateral
# pterygoid m.
# FIGURE 8.27  Muscles of Mastication. (From Atlas of human anatomy,  ed 7, Plate 55.)
# RETRIEVAL 2 posterior fibers
# retract mandible
# Masseter Zygomatic arch Ramus of mandible and
# coronoid processElevates and protrudes mandible;
# deep fibers retract mandible
# Lateral pterygoid Superior head : infratemporal surface
# of greater wing of sphenoid
# Inferior head : lateral pterygoid platePterygoid fovea, capsule
# of TMJ, articular discActing together, protrude
# mandible; acting alone and
# alternately,
# PREDICTION: Masseter
#
#
# -----------------------------------
#
#
# Which of the following structure is not present on floor of third ventricle?
#
# Optic stalk
# Third nerve
# Infundibulum
# Mammillary body
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Which
# structure is not routinely palpable from this
# perspective?
#  A. Inferior left pulmonary vein
#  B. Inferior right pulmonary vein
#  C. Inferior vena cava
#  D. Right atrium
#  E. Superior vena cavaFor each statement below (33 to 37), select the
# nerve or ner ve ﬁbers that are most likely responsible
# for the function described or the disorder caused
# (i.e., the single best answer).
# RETRIEVAL 2 hemispheres
# Olfactory cortex
# Hippocampus
# Basal ganglia/corpus striatum
# Lateral and 3rd ventricles Nerves: Olfactory (I)
# Forebrain
# DiencephalonOptic cup/nerves
# Thalamus
# Hypothalamus
# Mammillary bodies
# Part of 3rd ventricleOptic (II)
# Midbrain MesencephalonTectum
# Cerebral aqueduct
# Red nucleus
# Substantia nigra
# Crus
# PREDICTION: Optic stalk
#
#
# -----------------------------------
#
#
# Reticular fibers of collagen tissues are present in all of the following except:
#
# Thymus
# Spleen
# Bone marrow
# Lymph node
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Which of the following
# tissues or structures is most likely the mal-
# formed one?
#  A. Biceps muscle
#  B. Epidermis of the arm
#  C. Epithelium of the trachea
#  D. Dermis of the hand
#  E. Femur
# 30. Which of the following approaches is the best
# one for imaging bony structures because it
# subjects the patient to the lowest dosage of
# x-rays but is still highly accurate?
# RETRIEVAL 2 29. C.  The only tissue listed that is derived from the
# embryonic endoderm is the epithelial lining of
# the trachea. The epidermis is derived from the
# ectoderm, and all the other options are derived
# from the mesoderm.
# 30. C.  Plain radiography uses the lowest dosage of
# x-rays. CT is often a good way to image bony
# structures but uses a higher dosage of x-rays.
# None of the other imaging modalities use
# x-rays.
# PREDICTION: Bone marrow
#
#
# -----------------------------------
#
#
# Which is a direct content of cavernous sinus?
#
# Ophthalmic division of trigeminal nerve
# Trochlear nerve
# Abducent nerve
# Oculomotor nerve
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Fig. 8.16  lists the spec iﬁc nerves for each division.
# All the sensory neurons in CN V reside in the
# trigeminal (semilunar, gasserian) ganglion.  he
# trigeminal nerve is divided as follows:
# • Ophthalmic (CN V 1) division:  exits the skull
# via the superior orbit al ﬁssure.
# RETRIEVAL 2 2. D.  The supraorbital nerve is a branch of the
# ophthalmic division of the trigeminal nerve,
# and its distribution matches the description
# of the skin eruptions. The virus responsible for
# herpes resides in the sensory ganglia of nerves,
# in this case the semilunar ganglion of CN V.
# 3. D.  The expansion to the right side will affect the
# right eye and orbit, and in this case it will affect
# the oculomotor nerve (CN III).
# PREDICTION: Ophthalmic division of trigeminal nerve
#
#
# -----------------------------------
#
#
# Pre-maxillary hard palate is supplied by which nerve
#
# Nasopalatine nerve
# Pharyngeal branch of glossopharyngeal nerve
# Greater palatine nerve
# Tensor palatine nerve
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Sensory innervation of the hard palate is largely
# via the nasopalatine  and greater palatine nerves
# (CN V 2), whereas sensory innervation of the soft
# palate is largely through the lesser palatine nerves
# (CN V 2) (Fig. 8.43 ). he muscles of the soft palate
# and their actions are summarized in Table 8.12 .
# RETRIEVAL 2 of greater palatine nerve (CN V 2)Internal nasal branches of
# infraorbital nerve (CN V2) External nasal branches of
# anterior ethmoidal nerve (CN V1)Olfactory nerves (CN I)
# Posterior superior lateral nasal
# branch of maxillary nerve (CN V 2)
# FIGURE 8.38  Nerve Supply of the Nose (septum hinged open).
# PREDICTION: Greater palatine nerve
#
#
# -----------------------------------
#
#
# All the following muscles of larynx are supplied by the recurrent laryngeal nerve except:
#
# Cricohyoid
# Cricothyroid
# Arytenoid
# Aryepiglotticus
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 9. C.  The recurrent laryngeal (inferior laryngeal) nerve
# passes through the neck in the tracheo-
# esophageal groove as it ascends to innervate
# the muscles of the larynx. If injured, the only
# pair of abductors of the vocal folds would be
# compromised ipsilaterally (hemiparalysis of the
# posterior cricoarytenoids), leading to a hoarse
# voice.
# 10.
# RETRIEVAL 2 524 Chapter 8 Head and Neck
# the cricothyroid muscle, which is innervated by
# the external branch of the superior laryngeal nerve
# (CN X).  Sensation above the vocal folds is conveyed
# by the superior laryngeal nerve of CN X and by
# the recurrent laryngeal nerve below the vocal folds.
# he vocal folds (vocal ligaments covered with
# mucosa) control phonation as a reed might function
# in an instrument.
# PREDICTION: Cricohyoid
#
#
# -----------------------------------
#
#
# All of the following are developed from Meckel's cartilage except:
#
# Zygomatic bone
# Malleus
# Incus
# Stapes
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 554 Chapter 8 Head and Neck
# 13. A.  The ﬁrst pharyngeal arch gives rise to Meckel’s
# cartilage, and derivatives of this arch cartilage
# include the ossiﬁed mandible, malleus, incus,
# and sphenomandibular ligament. The sensory
# innervation comes from the mandibular division
# of the trigeminal nerve.
# 14.
# RETRIEVAL 2 Derivatives of arch cartilages
# Malleus, incus, sphenomandibular ligament
# Stapes, styloid process, stylohyoid ligament, upper half of hyoid
# Lower half and greater horns of hyoidThyroid and epiglottic cartilages
# Cricoid, arytenoid, and corniculate cartilagesFuture sphenomandibular lig.
# Portion mandibular bone surrounds
# FIGURE 8.77  Pharyngeal Arches.
# PREDICTION: Zygomatic bone
#
#
# -----------------------------------
#
#
# Action of the muscle marked (with arrow) on mandible is
#
# Elevation
# Depression
# Retraction
# Protraction
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 protrude mandible; acting alone,
# protrudes side of jaw; acting
# alternately, produces grinding
# motion
# *All innervated by CN V 3.
# Buccinator m.
# (not muscle of
# mastication—VII)Parotid ductDeep part
# Superficial partTemporal
# fasciaArticular
# tubercle
# Sphenomandibular
# lig.Medial
# pterygoid m.
# Parotid duct
# Buccinator m.
# RETRIEVAL 2 posterior fibers
# retract mandible
# Masseter Zygomatic arch Ramus of mandible and
# coronoid processElevates and protrudes mandible;
# deep fibers retract mandible
# Lateral pterygoid Superior head : infratemporal surface
# of greater wing of sphenoid
# Inferior head : lateral pterygoid platePterygoid fovea, capsule
# of TMJ, articular discActing together, protrude
# mandible; acting alone and
# alternately,
# PREDICTION: Protraction
#
#
# -----------------------------------
#
#
# Among all of the following foramens in the base of skull, which is, the most posteriorly present:
#
# Foramen spinosum
# Foramen rotundum
# Foramen ovale
# All at same level
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Imprints of these meningeal
# Foramen cecum
# Anterior ethmoidal foramen
# Foramina of cribriform plate
# Posterior ethmoidal foramen
# Optic canal
# Superior orbital fissure
# Foramen rotundum
# Foramen ovale
# Foramen spinosum
# Foramen lacerum
# Hiatus for
# Hiatus for
# Internal acoustic meatus
# Jugular foramen
# Hypoglossal canal
# Foramen magnumEmissary v.
# RETRIEVAL 2 A. Cavernous sinus
#  B. Inferior sagittal sinus
#  C. Pterygoid plexus of veins
#  D. Sigmoid sinus
#  E. Straight sinus
# 32. A hard blow to the head at the union of the
# frontal, parietal, sphenoid, and temporal bones
# is extremely dangerous; the resulting fracture
# can lead to an intracranial hemorrhage. Which
# of the following terms describes this unique
# area of the skull?
# PREDICTION: Foramen ovale
#
#
# -----------------------------------
#
#
# Lymph from tongue not drained by following vessels
#
# Central
# Ventral
# Posterior
# Marginal
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Most of the
# lymph ultimately drains back into the venous
# system by which of the following structures?
#  A. Arachnoid granulations
#  B. Choroid plexus
#  C. Cisterna chyli
#  D. Right lymphatic duct
#  E. horacic duct
# 8. A patient experiencing a central nervous system
# (CNS) inlammatory process will be activating
# which of the following phagocytic glial cells?
# RETRIEVAL 2 pharynx and
# larynx during swallowing
# and speaking
# and Table 8.16 ). Venous drainage is via the pha-
# ryngeal venous plexus, the pterygoid plexus of veins,
# and the facial, lingual, and superior thyroid veins,
# all of which drain primarily into the internal jugular
# vein (see Fig.
# PREDICTION: Central
#
#
# -----------------------------------
#
#
# Upper lip is formed by the fusion of:
#
# Maxillary and lateral nasal process.
# Lateral nasal and median nasal process.
# Maxillary, lateral nasal, median nasal process.
# Maxillary, mandibular, lateral nasal, median nasal process.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Internally, the common oral-nasal cavity becomes
# subdivided by a horizontal plate separating the oral
# cavity from the nasal cavity ( Fig. 8.80 ). Fusion of
# the medial nasal processes gives rise to an inter-
# maxillary segment called the primary palate.
# Swellings of the maxillary prominence of the face
# form palatine shelves  that project medially and
# fuse along the midline to form the secondary
# palate.
# RETRIEVAL 2 of stomodeum (base of skull)
# Philtrum of upper lip (fusion of medial
# nasal processes)
# Primary palate  (median palatine
# process)
# Definitive nasal septum
# Broken lines border area formed from
# medial nasal processes and primary palate
# Medial palatine process  (primary palate
# contribution)
# Lateral palatine process  (secondary palate
# contribution)
# Arrow emerging from choanaMaxillary process of 1st arch
# Lateral palatine process  (secondary
# palate)
# Opening of
# PREDICTION: Maxillary and lateral nasal process.
#
#
# -----------------------------------
#
#
# All are structures lying deep to the hyoglossus muscle except:
#
# Hypoglossal nerve
# Lingual artery
# Stylohyoid muscle
# Geniohyoid muscle
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 4. B.  Of the listed muscles, only the genioglossus
# muscle is innervated by CN XII. The other two
# muscles innervated by CN XII are the hyoglos -
# sus and styloglossus muscles.
# 5.
# RETRIEVAL 2 502 Chapter 8 Head and Neck
# Styloid process
# Superior pharyngeal
# constrictor m.
# Stylopharyngeus m.
# Stylohyoid m.
# Hyoid bone Mylohyoid m. ( cut)
# Geniohyoid m.Styloglossus m.
# Palatoglossus m.
# Hyoglossus m.Genioglossus m.
# FIGURE 8.39  Tongue and Extrinsic Muscles.
# PREDICTION: Stylohyoid muscle
#
#
# -----------------------------------
#
#
# Injury to the right mandibular nerve as it passes through foramen ovale produces the following effects:
#
# Loss of taste from the anterior 2/3 of tongue
# Deviation of the tongue to the left
# Deviation of chin to left when mouth is opened
# Loss of general sensation to anterior 2/3 of tongue
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Chapter 8 Head and Neck  551 8
# ____ 17. Sharp trauma to the left infratemporal
# fossa results in the ipsilateral loss of taste on
# the anterior two thirds of the tongue.
# ____ 18. In a patient with some hearing loss
# in one ear, the Rinne test c onﬁrms that the
# tuning fork is heard better when placed beside
# the afected ear than when placed on the
# mastoid process.
# ____ 19.
# RETRIEVAL 2 compression,
# mandibular fractureLoss of sensation over face,
# jaws, anterior head, and most
# of the dura mater, loss of
# muscles of mastication and
# sensation over anterior two
# thirds of tongue (V 3), absent
# corneal reflex (V 1)Branchial motor
# (V3 only)Foramen rotundum
# (V2)
# Foramen ovale (V 3)
# Abducens Somatic motor Superior orbital
# fissureFracture,
# PREDICTION: Loss of taste from the anterior 2/3 of tongue
#
#
# -----------------------------------
#
#
# When a patient is asked to say 'ah' , if the uvula is drawn upwards to the left, the cranial nerve likely to be damaged is
#
# Vagus
# Rt accessory
# Lt accessory
# Hypoglossal
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Chapter 8 Head and Neck  539 8
# Clinical Focus 8-46
# Nerve Lesions (CN X and CN XII)
# A lesion of the vagus nerve  is easily detected by asking the patient to say “ah.” If the nerve is intact, the
# soft palate and uvula will elevate symmetrically. If the vagus nerve has a lesion on one side, the elevation will
# be asymmetrical, with the palate and uvula deviating away from the lesioned side.
# RETRIEVAL 2 The ipsilateral tongue
# will also show evidence of muscle atrophy.
# Uvular paralysis:  uvula
# drawn to nonparalyzed
# side when patient says
# “A-AH”
# Hypoglossal nerve paralysis:
# tongue deviates toward
# paralyzed side when protruded
# Vagus nerve paralysis:  accumulation of saliva in
# piriform fossa on affected side due to cricopharyngeal
# muscle paralysis and inability to swallow.
# Paramedian vocal cord with poor or no movement
# due to paralysis.
# PREDICTION: Vagus
#
#
# -----------------------------------
#
#
# Anterior limit of infratemporal fossa is:
#
# Lateral pterygoid plate
# Maxillary posterior wall
# Pterygomaxillary fissure
# Mastoid process
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Chapter 8 Head and Neck  487 8
# maxillary and super ﬁcial temporal arteries. he
# temporal fossa  lies superior to the zygomatic arch,
# and the infratemporal fossa  is a wedge-shaped
# area inferior and deep to the zygomatic arch. he
# lateral wall of this fossa is formed by the mandibular
# ramus.
# RETRIEVAL 2 Chapter 8 Head and Neck  497 8
# Maxillary vv.
# Facial v.Superior ophthalmic v.
# FIGURE 8.32  Pterygoid Plexus of Veins in Infratemporal
# Fossa. (From Atlas of human anatomy,  ed 7, Plate 84.)
# Ethmoidal cells (sinuses)
# Frontal sinus
# Semilunar hiatus
# Uncinate process
# Inferior nasal
# concha (turbinate)
#
# Frontal
# PREDICTION: Pterygomaxillary fissure
#
#
# -----------------------------------
#
#
# The 3 embryonic germ layers: ectoderm, mesoderm and endoderm are derived from:
#
# Epiblast only
# Ectoderm from epiblast; mesoderm and endoderm from hypoblast
# Ectoderm and mesoderm from epiblast; endoderm from hypoblast
# Hypoblast only
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Finally, the surface epiblast cells form
# the ectoderm , the third germ layer. All body tissues
# are derived from one of these three embryonic germ
# layers.
# Embryonic Germ Layer Derivatives
# Figs. 1.36 to 1.38  and the accompanying tables
# provide a general overview of the adult derivatives
# of the three embryonic germ layers that are formed during gastrulation.
# RETRIEVAL 2 29. C.  The only tissue listed that is derived from the
# embryonic endoderm is the epithelial lining of
# the trachea. The epidermis is derived from the
# ectoderm, and all the other options are derived
# from the mesoderm.
# 30. C.  Plain radiography uses the lowest dosage of
# x-rays. CT is often a good way to image bony
# structures but uses a higher dosage of x-rays.
# None of the other imaging modalities use
# x-rays.
# PREDICTION: Ectoderm and mesoderm from epiblast; endoderm from hypoblast
#
#
# -----------------------------------
#
#
# Which of the following is developed from the 1st arch:
#
# Stylohyoid ligament.
# Spenomandibular ligament.
# Stapes.
# Styloid process.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Derivatives of arch cartilages
# Malleus, incus, sphenomandibular ligament
# Stapes, styloid process, stylohyoid ligament, upper half of hyoid
# Lower half and greater horns of hyoidThyroid and epiglottic cartilages
# Cricoid, arytenoid, and corniculate cartilagesFuture sphenomandibular lig.
# Portion mandibular bone surrounds
# FIGURE 8.77  Pharyngeal Arches.
# RETRIEVAL 2 554 Chapter 8 Head and Neck
# 13. A.  The ﬁrst pharyngeal arch gives rise to Meckel’s
# cartilage, and derivatives of this arch cartilage
# include the ossiﬁed mandible, malleus, incus,
# and sphenomandibular ligament. The sensory
# innervation comes from the mandibular division
# of the trigeminal nerve.
# 14.
# PREDICTION: Stapes.
#
#
# -----------------------------------
#
#
# True about occulomotor nerve are all except
#
# Carries parasympathetic fibres
# Causes constriction of pupils
# Supplies inferior oblique muscle
# Passes through inferior orbital fissure
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Postganglionic
# parasympathetic ibers then course via short ciliary
# nerves  to the eyeball (these postganglionic ibers
# mediate pupillary constriction and accommodation
# of the lens by their action on the ciliary smooth
# muscle). he trochlear nerve (CN IV) innervates
# the superior oblique muscle, and the abducens
# nerve (CN VI) innervates the lateral rectus muscle
# (Fig. 8.69 ).
# RETRIEVAL 2 These ﬁbers synapse in the ciliary ganglion and send
# postganglionic ﬁbers to the pupillary constrictor muscle of each iris, which constricts the pupils symmetrically
# and bilaterally, limiting the light’s effect on the retina.
# Optic nervesLight
# Optic
# chiasmCiliary ganglionShort ciliary nerves
# Optic tract
# Superior colliculusPosterior commissure Pretectal nucleusRed nucleus
# Edinger-Westphal nucleusCN
# III
# Superior view Medial palpebral
# PREDICTION: Supplies inferior oblique muscle
#
#
# -----------------------------------
#
#
# Retraction of the protruded mandible is done by
#
# Medial Pterygoid
# Lateral pterygoid
# Masseter
# Temporalis
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Medial
# pterygoid m.
# Parotid duct
# Buccinator m.
# Pterygomandibular
# raphe
# Lateral viewArticular disc of
# temporomandibular joint
# Masseter m.Temporalis m.
# Lateral
# pterygoid m.
# FIGURE 8.27  Muscles of Mastication. (From Atlas of human anatomy,  ed 7, Plate 55.)
# RETRIEVAL 2 articular discActing together, protrude
# mandible; acting alone and
# alternately, produces side-to-side
# movements
# Medial pterygoid Deep head : medial surface of lateral
# pterygoid plate and palatine bone
# Superficial head : tuberosity of
# maxillaRamus of medial
# mandible, inferior to
# mandibular foramenElevates mandible; acting together,
# protrude mandible; acting alone,
# protrudes side of jaw; acting
# alternately,
# PREDICTION: Medial Pterygoid
#
#
# -----------------------------------
#
#
# Type of skull seen in Beckwith hypoglycemic syndrome and fanconi syndrome:
#
# Platycephaly.
# Microcephaly.
# Anencephaly.
# Brachcephaly.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 A newborn female presents with a congenital
# neural tube defect likely caused by a folic acid
# deiciency and characterized by the failure of
# the sclerotome to form the neural arch. Which
# of the following conditions is consistent with
# this congenital defect?
#  A. Osteophyte overgrowth
#  B. Osteoporosis
#  C. Scoliosis
#  D. Spina biida
#  E. Spondylolysis
#   Multiple-choice and short-answer review questions available online; see inside front cover for details.
# RETRIEVAL 2 Small tumors in key brain areas can lead to seizures,
# hemiparesis, or aphasia. Increased ICP can initiate broader damage by compressing critical brain structures.
# Early symptoms of increased ICP include malaise, headache, nausea, papilledema, and less often abducens
# nerve palsy and Parinaud’s syndrome. Classic signs of hydrocephalus are loss of upward gaze, downward
# ocular deviation (“setting sun” syndrome), lid retraction, and light-near dissociation of pupils.
# PREDICTION: Brachcephaly.
#
#
# -----------------------------------
#
#
# True statements about osteoblasts are all except:
#
# Derived from osteoprogenitor cells
# Regulated by BM P
# Have a plasma membrane showing multiple folds
# Have neuropeptide receptors
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 A. Astrocytes
#  B. Ependymal cells
#  C. Microglia
#  D. Oligodendrocytes
#  E. Schwann cells
# Multiple-choice and short-answer review questions available online; see inside front cover for details.
# RETRIEVAL 2 10. E.  Of the options, only Schwann cells are derived
# from the neural crest. While the arachnoid
# mater and pia mater are derived from neural
# crest cells (neither of these choices are options),
# the dura mater is derived from mesoderm.
# 11. K.  The only muscle of this group innervated by
# a cranial nerve is the trapezius muscle by the
# accessory nerve (CN XI).
# PREDICTION: Have neuropeptide receptors
#
#
# -----------------------------------
#
#
# What is the nerve supply of the angle of the jaw?
#
# Mandibular nerve
# Maxillary nerve
# Lesser occipital nerve
# Greater auricular nerve
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 540 Chapter 8 Head and Neck
# C1Ophthalmic arteryCiliary ganglion
# Optic nerve
# (CN II)
# Maxillary nerve
# (CN V2)
# Sphenoidal sinus
# Infraorbital nervePterygopalatine
# ganglion
# Maxillary sinus
# Descending
# palatine artery
# Greater and lesser
# palatine arteries
# and nervesInternal carotid artery (cerebral part)
# Abducens nerve (CN VI)
# Ophthalmic nerve (CN V1)Artery and nerve of pterygoid canal
# RETRIEVAL 2 [CN VII] and
# carotid plexus)
# Greater and lesser
# palatine nn.
# Nerve to lateral
# pterygoid n.
# and masseteric n.
# Nerves to tensor veli
# palatini and medial
# pterygoid nn.
# Buccal n.Mental n.
# Lingual n.Submandibular
# ganglion
# Nerve to
# mylohyoid n.
# Mandibular n.
# PREDICTION: Mandibular nerve
#
#
# -----------------------------------
#
#
# Compament of leg without neurovascular bundle?
#
# Anterior
# Lateral
# Deep posterior
# Superficial posterior
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 he Posterior Compartment Leg Muscles,
# Vessels, and Nerves
# he posterior compartment leg muscles are
# arranged into a supericial group (gastrocnemius,
# plantaris, soleus) and a deep group (remaining
# posterior compartment muscles). hese muscles
# exhibit the following general features ( Fig. 6.21  and
# Table 6.15 ):
# • Are primarily lexors of the foot at the ankle
# (plantarlexion) and lexors of the toes.
# RETRIEVAL 2 • Lateral compartment:  muscles that evert
# the foot at the ankle and weakly plantarlex
# the foot, are innervated by the supericial
# ibular nerve, and are supplied by the ibular
# artery.posterior compartment is further subdivided into
# the supericial and deep compartments. Moreover,
# the leg is ensheathed in a tight deep fascia, and
# some of the underlying muscle ibers actually attach
# to this fascial sleeve. hese muscle compartments
# may be summarized as follows ( Fig.
# PREDICTION: Anterior
#
#
# -----------------------------------
#
#
# Brachcephaly with narrow foramen magnum is seen in:
#
# Down syndrome.
# Fanconi syndrome.
# Achondroplasia.
# Cleidocranial dysplasia.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 The disorder occurs in about 1 in 2000 births and is more common in men than in women.
# Sagittal ridge
# Scaphocephaly due to sagittal craniosynostosis
# Limitation of growth of coronal suturesLimitation of growth of sagittal suture
# Brachycephaly due to coronal craniosynostosis
# Clinical Focus 8-48
# Congenital Anomalies of the Oral Cavity
# Because the face and oral cavity develop largely by midline fusion of various prominences,
# RETRIEVAL 2 A newborn female presents with a congenital
# neural tube defect likely caused by a folic acid
# deiciency and characterized by the failure of
# the sclerotome to form the neural arch. Which
# of the following conditions is consistent with
# this congenital defect?
#  A. Osteophyte overgrowth
#  B. Osteoporosis
#  C. Scoliosis
#  D. Spina biida
#  E. Spondylolysis
#   Multiple-choice and short-answer review questions available online; see inside front cover for details.
# PREDICTION: Cleidocranial dysplasia.
#
#
# -----------------------------------
#
#
# Sensory supply of cornea is by?
#
# Infraorbital nerve
# Supraorbital nerve
# Infratrochlear nerve
# Nasolacrimal nerve (probably printing mistake - probably Nasociliary nerve).
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 • Nasociliary:  gives rise to short and long
# ciliary nerves, posterior and anterior ethmoidal
# nerves, and infratrochlear nerve; sensory to iris
# and cornea, sphenoid and ethmoid sinuses,
# lower eyelid, lacrimal sac, and skin of the
# anterior nose.
# he optic nerve  (CN II) is actually a brain tract
# that conveys sensory information from the retina,
# via the ganglion cell axons, to the brain (see Fig.
# 8.13).
# RETRIEVAL 2 2. D.  The supraorbital nerve is a branch of the
# ophthalmic division of the trigeminal nerve,
# and its distribution matches the description
# of the skin eruptions. The virus responsible for
# herpes resides in the sensory ganglia of nerves,
# in this case the semilunar ganglion of CN V.
# 3. D.  The expansion to the right side will affect the
# right eye and orbit, and in this case it will affect
# the oculomotor nerve (CN III).
# PREDICTION: Infratrochlear nerve
#
#
# -----------------------------------
#
#
# Abnormal development of a joint is known as:
#
# Synostosis.
# Dysostosis.
# Both
# None
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.Dysostosis
#
# Your response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again
#
# Synostosis.
#
# Dysostosis.
#
# Both
#
# None
# RETRIEVAL 1 • Long bone growth during childhood.
# • Epiphysial fusion occurring from puberty into
# maturity (early to mid-20s).
# Types of Joints
# Joints are the sites of union or articulation of two
# or more bones or cartilages, and are classiied into
# one of the following three types ( Fig. 1.8 ):
# • Fibrous  (synarthroses): bones joined by ibrous
# connective tissue.
# RETRIEVAL 2 Primary joints
# allow for growth and some bending, whereas
# secondary joints allow for strength and some
# lexibility.
# Synovial joints  generally allow for considerable
# movement and are classiied according to their
# shape and the type of movement that they permit
# (uniaxial, biaxial, or multiaxial movement) ( Fig.
# 1.9), as follows:
# • Hinge  (ginglymus): are uniaxial joints for lexion
# and extension.
# PREDICTION: Dysostosis
#
#
# -----------------------------------
#
#
# Located medial to the third molar at the junction of the maxilla and the horizontal plate of the palatine bone:
#
# Posterior nasal spine
# Mylohyoid line
# Pterygoid hamulus
# Greater palatine foramen
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Pterygoid hamulus
# Buccinator m.
# Pterygomandibular raphe
# Palatine tonsilAnterior view
# Transverse palatine folds
# Palatine process of
# maxillary bone
# Horizontal plate of palatine bone
# Superior pharyngeal constrictor m.Palatine aponeurosis
# (from tensor veli palatini m.)
# RETRIEVAL 2 Internally, the common oral-nasal cavity becomes
# subdivided by a horizontal plate separating the oral
# cavity from the nasal cavity ( Fig. 8.80 ). Fusion of
# the medial nasal processes gives rise to an inter-
# maxillary segment called the primary palate.
# Swellings of the maxillary prominence of the face
# form palatine shelves  that project medially and
# fuse along the midline to form the secondary
# palate.
# PREDICTION: Pterygoid hamulus
#
#
# -----------------------------------
#
#
# Buccinator is pierced by all of the following except:
#
# Labial branch of facial nerve
# Buccal branch of mandibular nerve
# Parotid duct
# Molar mucous glands
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Sublingual glandBuccinator m.
# Submandibular glandSubmandibular ganglionZygomatic branch
# Cervical branchMarginal mandibular branchBuccal branchParotid glandChorda tympaniPosterior auricular n.Stylomastoid foramen3
# 4Lingual n.TympanumStapedius m.21
# Tongue
# Sites of lesions and their manifestations (sites numbered in top image)
# 1.
# RETRIEVAL 2 he parotid duct  courses medially
# across the medial border of the masseter muscle
# and then dives deeply into the buccal fat pad,
# piercing the buccinator muscle  of the cheek and
# opening in the mouth just lateral to the second
# maxillary (upper) molar. As noted previously, the
# terminal portion of the facial nerve to the face (retraction), and protrusion of the mandible.
# PREDICTION: Molar mucous glands
#
#
# -----------------------------------
#
#
# Broca's area is related to
#
# Reading
# Sentence formation
# Word formation
# Comprehension
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 association cortex
# Corpus callosumVisual association cortex
# Primary visual cortex
# Cerebellum
# CerebellumCerebellumCorpus callosum
# Frontal pole4th ventricleLateral ventricleFrontal pole
# Medulla oblongataMedulla oblongataMidbrain
# Inferior nasal conchaInferior nasal conch a
# NasopharynxOccipital pole
# PonsPons
# Pituitary gland
# Sphenoid sinus
# Spinal cordThalamus
# Tentorium
# RETRIEVAL 2 8.5 ), circulates through
# these ventricles and then enters the subarachnoid
# Limbic cingulate cortex
# Thalamus
# Pituitary gland
# PonsSupplemental motor cortex
# Medulla oblongataFrontal
# LimbicPrimary motor cortex
# Medial aspect of the brain and brainstem
# Paramedian sagittal MR image Median sagittal MR imageParietal
# OccipitalSomatosensory association cortex
# Corpus callosumVisual association cortex
# Primary visual
# PREDICTION: Sentence formation
#
#
# -----------------------------------
#
#
# Loss of flexion in the interphalangeal joint of thumb in supracondylar fracture is due to involvement of which nerve
#
# Anterior interosseous
# Posterior interosseous
# Median
# Ulnar
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Ruptured medial collateral ligament of
# metacarpophalangeal joint of thumbTransverse fractures of
# metacarpal shaft usually
# angulated dorsally by
# pull of interosseous musclesFracture of metacarpals
# Thumb injury other than fractureFlexor digitorum profundus tendon may
# be torn directly from distal phalanx
# or may avulse small or large bone fragment.
# RETRIEVAL 2 A patient presents with numbness over his
# medial hand and atrophy of the hypothenar
# muscles after an injury several days ago over
# his medial humeral epicondyle. Which of the
# following nerves most likely was injured?
#  A. Anterior interosseous
#  B. Musculocutaneous
#  C. Recurrent branch of median
#  D. Supericial radial
#  E. Ulnar
# Multiple-choice and short-answer review questions available online;
# see inside front cover for details.
# PREDICTION: Median
#
#
# -----------------------------------
#
#
# Incus and malleus are derived from:
#
# Dorsal end of meckels cartilage.
# Ventral end of meckels cartilage.
# Inferior end of meckels cartilage.
# Any of the above.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.Dorsal end of Meckel's cartilage.
#
# Your response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again
#
# Dorsal end of meckels cartilage.
#
# Ventral end of meckels cartilage.
#
# Inferior end of meckels cartilage.
#
# Any of the above.
# RETRIEVAL 1 554 Chapter 8 Head and Neck
# 13. A.  The ﬁrst pharyngeal arch gives rise to Meckel’s
# cartilage, and derivatives of this arch cartilage
# include the ossiﬁed mandible, malleus, incus,
# and sphenomandibular ligament. The sensory
# innervation comes from the mandibular division
# of the trigeminal nerve.
# 14.
# RETRIEVAL 2 Derivatives of arch cartilages
# Malleus, incus, sphenomandibular ligament
# Stapes, styloid process, stylohyoid ligament, upper half of hyoid
# Lower half and greater horns of hyoidThyroid and epiglottic cartilages
# Cricoid, arytenoid, and corniculate cartilagesFuture sphenomandibular lig.
# Portion mandibular bone surrounds
# FIGURE 8.77  Pharyngeal Arches.
# PREDICTION: Dorsal end of Meckel's cartilage.
#
#
# -----------------------------------
#
#
# Which of the following marked muscles is Involved in Opening of jaw?
#
# A
# B
# C
# D
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Exami -
# nation reveals that she has an inlamed TMJ.
# Which of the following muscles is most likely
# involved in this inlammatory process?
#  A. Buccinator
#  B. Lateral pterygoid
#  C. Masseter
#  D. Medial pterygoid
#  E. Temporalis
# For each condition described below (15-25), select
# the nerve from the list (A-Q) that is most likely
# responsible for the condition or afected by it.
#  (A) Abducens
# RETRIEVAL 2 Which of the following muscles is
# most likely involved in this instance?
#  A. Adductor magnus muscle
#  B. Gastrocnemius muscle
#  C. Popliteus muscle
#  D. Short head of biceps femoris muscle
#  E. Vastus lateralis muscle
# For each condition described in questions 30 to 36,
# select the nerve from the list (A-K) that is most
# likely responsible for the condition or afected by it.
# PREDICTION: B
#
#
# -----------------------------------
#
#
# Auriculotemporal nerve encircles which artery
#
# Superficial temporal artery
# Superficial temporal vein
# Middle meningeal artery
# Deep temporal
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 he super icial temporal
# artery  supplies the scalp and upper face via its
# transverse facial branch. he maxillary artery
# supplies the infratemporal region, nasal cavities, • Meningeal:  small nerve that accompanies the
# middle meningeal artery through the foramen
# spinosum;  sensory to the dura mater.
# RETRIEVAL 2 8.17 ):
# • Facial artery:  arises from the external carotid
# artery.
# • Super icial temporal artery:  one of the
# two terminal branches of the external carotid
# artery.• Buccal.
# • Marginal mandibular.
# • Cervical.
# he sensory innervation of the face is by the
# three divisions of the trigeminal nerve  (CN V),
# with some contributions by the cervical plexus.
# Fig. 8.16  lists the spec iﬁc nerves for each division.
# PREDICTION: Superficial temporal artery
#
#
# -----------------------------------
#
#
# The primitives palate is formed from:
#
# Frontonasal process.
# 2 palatal process.
# Maxillary process.
# All of the above.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Internally, the common oral-nasal cavity becomes
# subdivided by a horizontal plate separating the oral
# cavity from the nasal cavity ( Fig. 8.80 ). Fusion of
# the medial nasal processes gives rise to an inter-
# maxillary segment called the primary palate.
# Swellings of the maxillary prominence of the face
# form palatine shelves  that project medially and
# fuse along the midline to form the secondary
# palate.
# RETRIEVAL 2 of stomodeum (base of skull)
# Philtrum of upper lip (fusion of medial
# nasal processes)
# Primary palate  (median palatine
# process)
# Definitive nasal septum
# Broken lines border area formed from
# medial nasal processes and primary palate
# Medial palatine process  (primary palate
# contribution)
# Lateral palatine process  (secondary palate
# contribution)
# Arrow emerging from choanaMaxillary process of 1st arch
# Lateral palatine process  (secondary
# palate)
# Opening of
# PREDICTION: All of the above.
#
#
# -----------------------------------
#
#
# Lateral movement of condyle takes place by:
#
# Contralateral lateral pterygoid
# Ispilateral lateral pterygoid
# Same side medial pterygoid
# None of the above
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 articular discActing together, protrude
# mandible; acting alone and
# alternately, produces side-to-side
# movements
# Medial pterygoid Deep head : medial surface of lateral
# pterygoid plate and palatine bone
# Superficial head : tuberosity of
# maxillaRamus of medial
# mandible, inferior to
# mandibular foramenElevates mandible; acting together,
# protrude mandible; acting alone,
# protrudes side of jaw; acting
# alternately,
# RETRIEVAL 2 Sometimes these
# terms of relationship are used in combination (e.g.,
# superomedial,  meaning closer to the head and nearer
# the median sagittal plane).
# Movements
# Body movements usually occur at the joints where
# two or more bones or cartilages articulate with
# one another. Muscles act on joints to accomplish
# these movements and may be described as
# follows: “he biceps muscle lexes the forearm
# at the elbow. ” Fig. 1.3  summarizes the terms of
# movement.
# PREDICTION: Ispilateral lateral pterygoid
#
#
# -----------------------------------
#
#
# All the following nerves are related to the mandible except:
#
# Lingual nerve
# Auriculotemporal nerve
# Chorda tympani
# Mental nerve
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 V)
# (mandibular nerve [CN V 3])
# via lingual nerve
# (general sensation)
# FIGURE 8.41  Sensory Innervation of Tongue. (From Atlas of human anatomy,  ed 7, Plate 66.)
# • Facial:  via chorda tympani nerve , which joins
# the lingual nerve; provides taste on the anterior
# two thirds of the tongue.
# • Glossopharyngeal:  general sensation and taste
# on the posterior third of the tongue.
# RETRIEVAL 2 (CN VII)
# Temporal
# branches
# Zygomatic
# branches
# Buccal
# branches
# Marginal
# mandibular
# branchCervical branchEfferent fibers
# Afferent fibers
# Parasympathetic fibers
# Sympathetic fibers
# Sublingual gland
# Submandibular glandSubmandibular ganglionLingual n. (from trigeminal n.)
# Stylomastoid foramen
# Posterior auricular n.Occipital branch of
# posterior auricular n.
# PREDICTION: Auriculotemporal nerve
#
#
# -----------------------------------
#
#
# Liver is divided into eight segments according to Couinaud's classification based upon
#
# Bile Duct
# Poal vein
# Hepatic Vein
# Hepatic aery
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Surgically  the liver is divided into right and left
# anatomical lobes and is then further subdivided
# into eight functional segments based largely on the
# intrahepatic distribution of vessels and bile ducts;
# the divisions are useful for partial hepatectomy and/
# or the excision of metastatic nodules or speciic
# segments. For gross anatomists, the quadrate and loop of bowel that runs medially to join the
# midline rectum in the pelvis.
# RETRIEVAL 2 Proper hepatic a.
# Common hepatic a.
# Hepatic ducts
# Cystic ductRight Left
# Spiral
# foldSmooth
# part
# Common
# hepatic ductNeck
# Infundibulum
# (Hartmann's
# pouch)
# Body
# Fundus
# Hepatopancreatic ampulla (of Vater)
# Major duodenal papilla (of Vater)Descending (2nd)
# part of duodenum
# Pancreatic duct(Common )
# bile duct Common hepatic ductIntrahepatic
# PREDICTION: Bile Duct
#
#
# -----------------------------------
#
#
# True about Levator Ani except -
#
# Converge downwards & medially
# Suppos viscera
# Made up of iliococcygeus & pubococcygeus
# Attached to pelvic brim
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 5.4  and Table 5.2 ). he levator ani muscle
# consists of three muscle groups intermingled to
# form a single sheet of muscle (iliococcygeus,
# pubococcygeus, and puborectalis muscles). he
# levator ani muscle is an important support structure
# for the pelvic viscera in bipeds (upright-walking
# humans) and helps maintain closure of the vagina
# and rectum.
# RETRIEVAL 2 Contraction of
# this muscle empties the urinary bladder and
# is under parasympathetic control.
# 16. K.  The levator ani is one of two muscles compris -
# ing the pelvic diaphragm (the other one is the
# coccygeus), and is itself really the amalgam
# of three separate but closely associated
# muscles (the puborectalis, pubococcygeus,
# and iliococcygeus) that is commonly referred
# to as the levator ani.
# PREDICTION: Converge downwards & medially
#
#
# -----------------------------------
#
#
# Arterial supply to floor of mouth & suprahyoid muscle is
#
# Lingual artery
# Maxillary artery
# Inferior alveolar artery
# Facial artery
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 8.71 ). Secretomo-
# tor postganglionic parasympathetic ﬁbers then
# innervate the submandibular and sublingual salivary
# glands.
# Vascular Supply
# he external carotid artery terminates as the
# super ﬁcial temporal and maxillary arteries (see Fig.
# 8.17 and Table 8.16 ). he super icial temporal
# artery  supplies the scalp and upper face via its
# transverse facial branch.
# RETRIEVAL 2 he blood supply to the man-
# dibular teeth comes from the inferior alveolar artery
# (branch of the maxillary artery). he venous drain -
# age is from corresponding veins, most of which
# drain into the pterygoid plexus of veins in the
# infratemporal fossa.
# 11.  NECK
# he neck is divided descriptively into two major
# triangles.
# PREDICTION: Maxillary artery
#
#
# -----------------------------------
#
#
# Lesion of the marked structure affects all EXCEPT (AIIMS May 2019)
#
# Superior rectus
# Superior oblique
# Inferior oblique
# Medial rectus
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 15. A.  Inability to abduct the eye without other move -
# ment impairment suggests that the lateral
# rectus muscle is affected, and it is innervated
# by the abducens nerve (CN VI).
# 16. D.  Partial ptosis (denervation of the superior tarsal
# muscle) and pupillary constriction (absence of
# pupillary dilation) suggest an injury to the
# sympathetic system somewhere along its
# pathway to the head.
# RETRIEVAL 2 8.20  and
# Table 8.6 ). In addition to the movements of eleva-
# tion, depression, abduction, and adduction, the
# superior rectus and superior oblique muscles
# medially rotate (intorsion) the eyeball, and the
# inferior rectus and inferior oblique muscles laterally
# rotate (extorsion) the eyeball.
# PREDICTION: Medial rectus
#
#
# -----------------------------------
#
#
# Which of the following projects efferent fibers through the marked structure:-
#
# Hippocampus
# Mammillary body
# Caudate nucleus
# Amygdala
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 MesencephalonTectum
# Cerebral aqueduct
# Red nucleus
# Substantia nigra
# Crus cerebelliOculomotor (III)
# Trochlear (IV)
# MetencephalonPons
# Cerebellum
# Hindbrain
# Myelencephalon Medulla oblongataTrigeminal (V)
# Abducens (VI)
# Facial (VII)
# Vestibulocochlear (VIII)
# Glossopharyngeal (IX)
# Vagus (X)
# Hypoglossal
# RETRIEVAL 2 (From Atlas of human anatomy , ed 7, Plate 64.)
# Efferent fibers
# Afferent fibers
# Parasympathetic fibersTympanic n. (of Jacobson)
# Tympanic cavity and plexus
# Lesser petrosal n.
# Pterygopalatine ganglion
# Mandibular n.
# PREDICTION: Mammillary body
#
#
# -----------------------------------
#
#
# Passavant’s ridge is located on which of the following:
#
# Posterior wall of oropharynx
# Anterior wall of oropharynx
# Posterior wall of nasopharynx
# Anterior wall of nasopharynx
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 The soft palate is drawn upward as a
# bulge forms in the upper part of posterior
# pharyngeal wall (Passavant’s ridge) and
# approaches the rising soft palate.Bolus
# B. As tongue gradually presses more of its dorsal
# surface against the hard palate, the bolus is
# pushed posteriorly into the oropharynx. The soft
# palate is drawn superiorly to contact Passavant’s
# ridge and closes off the nasopharynx.
# RETRIEVAL 2 518 Chapter 8 Head and Neck
# • Nasopharynx:  lies posterior to the nasal cavity
# above the soft palate.
# • Oropharynx:  extends from the soft palate to
# the superior tip of the epiglottis; it is the region
# ...
# RETRIEVAL 2 Clinical Focus 8-47
# Craniosynostosis
# As the brain grows, so does the neurocranium, by bone deposition along suture lines. If this process is
# interrupted (for unknown reasons or because of genetic factors), the cranium may compensate by depositing
# more bone along other sutures.
# PREDICTION: Scaphocephaly.
#
#
# -----------------------------------
#
#
# Dorsal part of 2nd pouch give rise to:
#
# Tonsils.
# Thymus.
# Tubotympanic recess.
# Tympanic antrum.
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 • Pouch 2:  tonsillar fossa and the epithelium of
# the palatine tonsils (the lymphoid tissue of the
# tonsil is derived from mesoderm).
# • Pouch 3:  inferior parathyroid glands and thymus
# gland.• Pouch 4:  superior parathyroid glands and C cells
# (parafollicular cells; calcitonin-secreting cells)
# of the thyroid gland.
# RETRIEVAL 2 pouch
# 3rd pharyngeal pouchAuditory tube
# Tympanic cavity
# Eardrum
# External acoustic meatus
# Auricle
# Nasopharynx
# Tongue ( cut)
# Foramen cecum
# Persistent thyroglossal duct
# Aberrant parathyroid gland III
# Pharyngeal fistula
# Parathyroid gland IV
# Ultimobranchial body
# Pyramidal and lateral
# lobes of thyroid gland
# Parathyroid gland III
# Persistent cord of thymus
# Pharyngeal
# PREDICTION: Tonsils.
#
#
# -----------------------------------
#
#
# Soft palate is made up of:
#
# Palatoglossus and palatopharyngeus
# Uvula
# Mucous membrane and muscles
# All of the above
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 504 Chapter 8 Head and Neck
# maxilla and horizontal process of the palatine
# bone ( Fig. 8.45 ); covered by a thick mucosa that
# overlies numerous mucus-secreting palatal
# glands.
# • Soft palate:  posterior third of the palate; com-
# posed of a mucosa and mucus-secreting palatal
# glands, wit h ﬁve muscles that contribute to the
# soft palate and its movements; close s of the
# nasopharynx during swallowing.
# RETRIEVAL 2 Palatoglossus m.
# Palatopharyngeus m.
# FIGURE 8.43  Oral Cavity With Partial Dissection of Palate. (From Atlas of human anatomy,  ed 7,
# Plate 67.)
# Medial pterygoid plate
# Pterygoid hamulus
# Tendon of tensor veli palatini m.
# Musculus uvulaeChoanae
# Pterygoid hamulusBasilar part of occipital bone
# Superior pharyngeal constrictor m.
# PREDICTION: Mucous membrane and muscles
#
#
# -----------------------------------
#
#
# Wrong statement regarding grey rami communicates is
#
# Connected to spinal nerve
# Present medial to white rami communicantes
# Carries pre-ganglionic fibres
# Fibres are non-myelinated
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 3.22 ). Each of the 11 or 12 pairs of ganglia
# (number varies) is connected to the anterior ramus
# of the corresponding spinal nerve by a white ramus
# communicans (the white ramus conveys pregan-
# glionic sympathe tic ﬁbers from the spinal nerve).
# A gray ramus communicans then conveys post-
# ganglionic sympathetic ﬁbers back into the spinal
# nerve and its anterior or posterior rami (see Chapter
# 1, Nervous System).
# RETRIEVAL 2 Gray and white rami communicantes
# FIGURE 2.14  Typical Spinal Nerve.
# Each of the 31 pairs of spinal nerves exits the
# spinal cord and passes through an opening in the
# vertebral column (intervertebral foramen) to gain
# access to the periphery .
# PREDICTION: Fibres are non-myelinated
#
#
# -----------------------------------
#
#
# Lower two pas of sternal body is fused by:
#
# 8 years
# 10 years
# 12 years
# 14 years
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Which of the following
# features also is found at the level of the sternal
# angle?
#  A. Articula tion of ﬁrst rib
#  B. Azygos vein
#  C. Descending aorta
#  D. Sinuatrial node
#  E. Tracheal bifurcation9. Auscultation of the lungs of a 31-year-old
# woman reveals crackles heard on the back along
# the right medial border of the scapula, just
# above the inferior scapular angle, during late
# inspiration.
# RETRIEVAL 2 notch
# Manubrium
# Angle
# Body
# Xiphoid
# processSternum
# Floating ribs (11-12)ScapulaAcromion
# Coracoid process
# Glenoid fossa (cavity)
# Subscapular fossaClavicle
# True ribs (1 –7)
# Costal cartilages
# False ribs (8–12)1
# 11
# 12AngleTubercle Neck Head
# Superior Inferior
# Articular facets
# for vertebral
# bodyArticular facet
# for transverse
# process
# PREDICTION: 12 years
#
#
# -----------------------------------
#
#
# Not a part of ethmoid bone is
#
# Inferior turbinate
# Agar nasi cells
# Uncinate process
# Crista galli
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 galli
# Cribriform plate
# Perpendicular plate
# Inferior nasal concha
# Anterior nasal spine
# Incisive canal
# Palatine process
# Nasal bone
# Ethmoid bone
# Lacrimal bone
# Inferior nasal concha
# Maxillary boneCribriform plate
# Superior nasal concha
# Middle nasal concha
# Palatine process
# Alveolar processTemporal bone
# Squamous part
# Petrous part
# Internal acoustic meatus
# Lambdoid sutureGroove for sigmoid sinus
# Occipital
# RETRIEVAL 2 dissectio nOrbital plate of frontal bone
# Coronal CT at the level of the crista galli showing
# the ethmoid and maxillary sinuses and nasal cavity.Ethmoid bulla
# Middle nasal concha eCrista galli
# Cribriform plate
# Orbit
# Infundibulum
# Uncinate process of
# ethmoid bone
# Middle meatus
# FIGURE 8.33  Paranasal Sinuses.
# PREDICTION: Crista galli
#
#
# -----------------------------------
#
#
# Extra-embryonic mesoderm is derived from:
#
# Epiblast
# Primary yolk sac
# Secondary yolk sac
# Hypoblast
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 he epiblast forms a cavity on the dorsal side
# that gives rise to the amniotic cavity. he blastocyst
# cavity on the ventral side becomes the primitive
# yolk sac, which is lined by simple squamous epi-
# thelium derived from the hypoblast. About day 12,
# further hypoblast cell migration forms the true yolk
# sac, and the old blastocyst cavity becomes coated
# with extraembryonic mesoderm.
# RETRIEVAL 2 Finally, the surface epiblast cells form
# the ectoderm , the third germ layer. All body tissues
# are derived from one of these three embryonic germ
# layers.
# Embryonic Germ Layer Derivatives
# Figs. 1.36 to 1.38  and the accompanying tables
# provide a general overview of the adult derivatives
# of the three embryonic germ layers that are formed during gastrulation.
# PREDICTION: Hypoblast
#
#
# -----------------------------------
#
#
# Finger with two dorsal interossei attached?
#
# Little
# Index
# Middle
# Ring
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 (from median n.)
# Interosseous membrane and
# extensor pollicis longus m.
# Posterior interosseous a. and n.
# (continuation of deep
# branch of radial n.)
# Median n.
# Flexor digitorum
# superficialis m. and tendons
# Ulnar a. and n.
# Flexor digitorum
# profundus m. and tendons
# Extensor digitorum tendons (common
# tendon to digits 4 and 5 at this level)Pronator quadratus m.
# RETRIEVAL 2 Central
# slip of extensor tendon often torn,
# requiring open fixation, followed
# by dorsal splinting.
# Rotational dislocation  (rare)
# Boutonnière deformity  of index
# finger with swan-neck deformity
# of other fingers in a patient with
# rheumatoid arthritisDorsal dislocation  of proximal interphalangeal joint
# with disruption of volar plate and collateral ligament
# may result in swan-neck deformity  and compensa-
# tory flexion deformity of distal interphalangeal joint.
# PREDICTION: Ring
#
#
# -----------------------------------
#
#
# Palatoglossus develops from:
#
# Occipital myotomes
# Lingual swelling of first arch
# Third arch
# Mesoderm of sixth arch
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Palatoglossus m.
# Palatopharyngeus m.
# FIGURE 8.43  Oral Cavity With Partial Dissection of Palate. (From Atlas of human anatomy,  ed 7,
# Plate 67.)
# Medial pterygoid plate
# Pterygoid hamulus
# Tendon of tensor veli palatini m.
# Musculus uvulaeChoanae
# Pterygoid hamulusBasilar part of occipital bone
# Superior pharyngeal constrictor m.
# RETRIEVAL 2 Clinical Focus 8-49  provides a composite
# summary of some of the more common clinical
# anomalies of the pharyngeal arch and pouch
# derivatives.
# Facial and Palatal Development
# he face develops primarily from the neural crest by
# the fusion of an unpaired frontonasal prominence
# Hindbrain  (metencephalon)
# Cranial n. VII (sensory and motor)
# Cranial n. VI (motor)
# Cranial n. V (sensory and motor)
# Cranial n.
# PREDICTION: Lingual swelling of first arch
#
#
# -----------------------------------
#
#
# Tendon of Gracilis, Sartorius and semitendenous muscles insert on tibia to form Pesanserinus. Similar structure is seen in
#
# TMJ
# Parotid
# Submandibular gland
# Cheek
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 (cut)
# Gracilis m. (cut)
# Tendon of semitendinosus m.
# Semimembranosus bursa
# Anserine bursa deep to
# Semitendinosus,
# Gracilis, and
# Sartorius tendons
# Gastrocnemius m.Tibial collateral lig.Gastrocnemius m.
# Pes anserinusSemimembranosus m.
# and tendonBursa deep to iliotibial tractBiceps femoris m.
# RETRIEVAL 2 E.  The gracilis is the third muscle of the pes
# anserinus (three toes of a goose’s foot). These
# muscle tendons help to stabilize the medial
# aspect of the knee.
# 20. B.  The biceps femoris (short head) is a muscle of
# the posterior compartment of the thigh but
# only ﬂexes the leg at the knee and does not
# cross the hip joint and extend the thigh at the
# hip, like the other three “hamstring” muscles.
# PREDICTION: TMJ
#
#
# -----------------------------------
#
#
# Efferent tracts from cerebellum arises from:
#
# Purkinje cells
# Deep cerebellar nuclei
# Cerebellar cortex
# Vermis of cerebellum
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 In general, CN I and CN II arise from the
# forebrain and are really tracts of the brain for the
# special senses of smell and sight. he other cranial
# nerves arise from the brainstem. Cranial nerves
# III, IV, and VI move the extraocular skeletal muscles Cranial Nerves
# Twelve pairs of cranial nerves arise from the brain,
# and they are identiied both by their names and by
# Roman numerals I to XII ( Fig. 1.22 ).
# RETRIEVAL 2 10. E.  Of the options, only Schwann cells are derived
# from the neural crest. While the arachnoid
# mater and pia mater are derived from neural
# crest cells (neither of these choices are options),
# the dura mater is derived from mesoderm.
# 11. K.  The only muscle of this group innervated by
# a cranial nerve is the trapezius muscle by the
# accessory nerve (CN XI).
# PREDICTION: Deep cerebellar nuclei
#
#
# -----------------------------------
#
#
# Epidural venous plexus is located in
#
# Basal ganglia adjacent to pons
# At the junction of middle and posterior cranial fossa
# In vertebral canal below duramater
# In vertebral canal above duramater
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 7. B.  The internal vertebral venous plexus (Batson’s
# plexus) resides in the epidural fat surrounding
# the meningeal-encased spinal cord. The epidural
# space lies between the bony vertebral spinal
# canal and the dura mater surrounding the spinal
# cord.
# RETRIEVAL 2 Internal vertebral (epidural) venous plexus (of Batson)Fat in
# epidural space
# Anterior root
# Anterior
# ramus
# Posterio r
# ramusDura mater
# Subarachnoid
# spaceArachnoid mater
# Pia mater
# Spinal ganglionSection through thoracic vertebra
# FIGURE 2.18  Spinal Meninges and Relationship to Spine. (From Atlas of human anatomy,  ed 7,
# Plates 174 and 175.)
# PREDICTION: In vertebral canal below duramater
#
#
# -----------------------------------
#
#
# All of the following structures lie in the relation to the left ureter except:
#
# Mesentery of sigmoid colon
# Bifurcation of common iliac aery
# Quadratus lumborum
# Gonadal vessels
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 A. Common iliac vessels
#  B. Lumbosacral trunk
#  C. Major renal calyx
#  D. Renal pelvis
#  E. Sacroiliac joint
# 9. An obese 46-year-old woman presents in the
# clinic with right upper quadrant pain for the
# past 48 hours, jaundice for the last 24 hours,
# nausea, and acute bouts of severe pain (biliary
# colic) after she tries to eat a meal.
# RETRIEVAL 2 8. A.  The ureter crosses the common iliac vessels
# about halfway on its journey to the urinary
# bladder. It is slightly stretched and its lumen
# narrowed as it crosses these vessels, so a
# calculus can become lodged at this point. This
# site also is close to the pelvic brim.
# 9. A.  The common bile duct is probably obstructed,
# causing the pain and jaundice.
# PREDICTION: Mesentery of sigmoid colon
#
#
# -----------------------------------
#
#
# In which of the following microvilli are not present?
#
# Gallbladder
# Duodenum
# Collecting duct
# Proximal convoluted tubule
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 Which of
# the following portions of the GI system can be
# excluded from further examination of the
# patient?
#  A. Ascending colon
#  B. Cecum
#  C. Ileum
#  D. Rectum
#  E. Sigmoid colon
# 27. A patient is having diiculty becoming pregnant.
# Her physician suspects a problem associated
# with the portion of her reproductive system
# that receives the ovulated oocyte. Which of
# the following structures is the focus of the
# physician’s concern?
# RETRIEVAL 2 A diagnosis
# of cholelithiasis (gallstones) is made. Which of
# the following structures is most likely obstructed
# by the stone?
#  A. Common bile duct
#  B. Cystic duct
#  C. Main pancreatic duct
#  D. Right hepatic duct
#  E. horacic duct
# 10.
# PREDICTION: Gallbladder
#
#
# -----------------------------------
#
#
# All of the following carry proprioception from head and neck except:
#
# Facial nerve
# Trigeminal nerve
# Glossopharyngeal nerve
# Cranial accessory nerve
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 536 Chapter 8 Head and Neck
# Efferent fibers
# Afferent fibers
# Proprioceptive fibers
# Parasympathetic fibers
# Sympathetic fibersOphthalmic n. (CN V1)
# Nasociliary n.
# Lacrimal n.
# Frontal n.
# Ciliary ganglion
# Anterior ethmoidal n.
# Supraorbital n.
# Supratrochlear n.
# Infratrochlear n.
# External nasal branches
# of anterior ethmoidal n.
# Maxillary n.
# RETRIEVAL 2 Of the listed nerves, only
# the deep petrosal (postganglionic ﬁbers from
# the superior cervical ganglion) nerve would
# show exclusively sympathetic involvement as
# it courses on the intracranial portion of the
# internal carotid artery.
# 17. C.  If taste is the only sense affected, the answer
# is the chorda tympani, which is damaged before
# joining the lingual nerve (apparently sensation
# on the anterior tongue is intact).
# PREDICTION: Facial nerve
#
#
# -----------------------------------
#
#
# Which of the following vessels supply the anal canal?
#
# Superior rectal aery
# Middle rectal aery
# Inferior rectal aery
# all of the following
#
# Respond with the correct choice from the list above verbatim.  Do not include any explanation.
# RETRIEVAL 1 See Clinical Focus 5-23 .
# 31. D.  The middle (and inferior) rectal veins and their
# branches are part of the caval system and
# anastomose with the branches of the superior
# rectal vein, a tributary of the inferior mesen-
# teric vein, which is part of the portal venous
# drainage.
# 32. C.  The only vessel in the list that travels through
# both the greater and lesser sciatic foramina
# is the internal pudendal artery.
# RETRIEVAL 2 he inferior mesenteric artery (7)  supplies the
# embryonic hindgut derivatives (distal transverse
# colon, descending colon, sigmoid colon, and
# proximal rectum).
# he abdominal aorta (1)  inally gives rise
# to three paired visceral arteries  that supply
# the adrenal (suprarenal) glands via the paired
# middle suprarenal arteries (8),  the kidneys via
# the paired renal arteries (9),  and the gonads via
# the paired ovarian or testicular arteries (10).
# PREDICTION: Middle rectal aery
#
#
# -----------------------------------

# %%
print("exact_match:", exact_match)
print("mismatch:", mismatch)
# Out:
# exact_match: 0.5299145299145299
# mismatch: 0.042735042735042736

# %% [markdown]
# # query engine 2

# %%
def predict2(prompt):
    return str(query_engine2.query(prompt))

def evaluate2():
  SAMPLE_CNT = len(dataset_validation)
  mismatch_cnt = 0
  predictions = []
  references = []

  for i in range(SAMPLE_CNT):
    example = dataset_validation[i]
    question, option_a, option_b, option_c, option_d = example["question"], example["opa"], example["opb"], example["opc"], example["opd"]
    prompt = f'''{question}

{option_a}
{option_b}
{option_c}
{option_d}

Respond with the correct choice from the list above verbatim.  Do not include any explanation.'''

    options = [example['opa'], example['opb'], example['opc'], example['opd']]
    correct_option = options[example['cop']]
    references.append(correct_option)

    prediction = predict2(prompt)
    if prediction not in options:
      prompt += prediction + "\n\nYour response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again\n\n" + example['opa'] + "\n\n" + example['opb'] + "\n\n" + example['opc'] + "\n\n" + example['opd']
      prediction = predict2(prompt)

    print("prediction ISSSSS", prediction)
    predictions.append(prediction)

    mismatch_cnt += prediction not in options

  exact_match = sum([prediction == reference for prediction, reference, in zip(predictions, references)]) / SAMPLE_CNT
  mismatch = mismatch_cnt / SAMPLE_CNT

  return exact_match, mismatch

exact_match, mismatch = evaluate2()
# Out:
# Generated queries:
# Which branches of the external carotid artery are in Kiesselbach's plexus?
# Which arteries make up Kiesselbach's plexus?
# What are the branches of the external carotid artery in Kiesselbach's plexus?
# Correct choice: Septal branch of superior labial artery
# Generated queries:
# Sphenopalatine aery
# Anterior ethmoidal aery
# Greater palatine aery
# prediction ISSSSS Sphenopalatine artery
# Generated queries:
# Cricoid cailage in respiratory tree
# Thyroid cailage in respiratory tree
# Cunieform cailage in respiratory tree
# prediction ISSSSS Cricoid cailage
# Generated queries:
# Root
# Division
# Cord
# prediction ISSSSS Root
# Generated queries:
# Chief cells proliferation in villi
# Goblet cells function in villi
# Paneth cells location in villi
# prediction ISSSSS Goblet cells
# Generated queries:
# Lateral pterygoid
# Temporalis
# Medial pterygoid
# prediction ISSSSS Lateral pterygoid
# Generated queries:
# Waldeyer's lymphatic chain is formed by all except Palatine tonsils
# Waldeyer's lymphatic chain is formed by all except Pharyngeal tonsils
# Waldeyer's lymphatic chain is formed by all except Tubal and lingual tonsils
# prediction ISSSSS Post auricular nodes
# Generated queries:
# Superficial temporal artery
# Facial artery
# Maxillary artery
# prediction ISSSSS Facial artery
# Generated queries:
# Visual cortex is present in the: Occipital lobe
# Visual cortex is present in the: Temporal lobe
# Visual cortex is present in the: Frontal lobe
# prediction ISSSSS Occipital lobe
# Generated queries:
# Ventral part of 3rd pouch.
# Ventral part of 2nd pouch.
# Dorsal part of 2nd pouch.
# prediction ISSSSS Ventral part of 3rd pouch.
# Generated queries:
# Branches of cervical plexus
# Vagus nerve
# Glossopharyngeal nerve
# prediction ISSSSS Branches of cervical plexus
# Generated queries:
# Optic stalk
# Third nerve
# Infundibulum
# prediction ISSSSS Optic stalk
# Generated queries:
# Reticular fibers of collagen tissues are present in Thymus
# Reticular fibers of collagen tissues are present in Spleen
# Reticular fibers of collagen tissues are present in Bone marrow
# Reticular fibers of collagen tissues are present in Lymph node
# Correct choice: Bone marrow
# prediction ISSSSS Bone marrow
# Generated queries:
# Ophthalmic division of trigeminal nerve
# Trochlear nerve
# Abducent nerve
# prediction ISSSSS Ophthalmic division of trigeminal nerve
# Generated queries:
# Nasopalatine nerve
# Pharyngeal branch of glossopharyngeal nerve
# Greater palatine nerve
# prediction ISSSSS Greater palatine nerve
# Generated queries:
# Which muscles of the larynx are supplied by the recurrent laryngeal nerve?
# Which muscles of the larynx are not supplied by the recurrent laryngeal nerve?
# Which muscles of the larynx are innervated by the recurrent laryngeal nerve?
# Correct choice: Cricohyoid
# prediction ISSSSS Cricohyoid
# Generated queries:
# Zygomatic bone
# Malleus
# Incus
# prediction ISSSSS Zygomatic bone
# Generated queries:
# Mylohyoid, anterior and posterior belly of digastric
# Mylohyoid, anterior belly of digastric, and tensor tympani
# Mylohyoid, posterior belly of digastric and tensor tympani
# prediction ISSSSS Mylohyoid, anterior belly of digastric, and tensor tympani
# Generated queries:
# Superior meatus
# Middle meatus
# Inferior meatus
# prediction ISSSSS Middle meatus
# Generated queries:
# Skin of the entire upper lip is supplied by:
# Maxillary nerve.
# Skin of the entire upper lip is supplied by:
# Facial nerve.
# Skin of the entire upper lip is supplied by:
# Mandibular nerve.
# prediction ISSSSS Maxillary nerve.
# Generated queries:
# A. What is the function of holocrine glands?
# B. How do holocrine glands differ from merocrine glands?
# C. What are examples of holocrine glands in the human body?
# prediction ISSSSS A
# Generated queries:
# Lower jaw.
# Both.
# None.
# prediction ISSSSS Both.
# Generated queries:
# Where are the special visceral afferent fibres of the facial nerve located: Motor nucleus
# Where are the special visceral afferent fibres of the facial nerve located: Nucleus ambiguous
# Where are the special visceral afferent fibres of the facial nerve located: Nucleus of tractus solitarius
# prediction ISSSSS Nucleus of tractus solitarius
# Generated queries:
# Elevation
# Depression
# Retraction
# prediction ISSSSS Elevation
# Generated queries:
# Which muscle is innervated by the vagus nerve?
# What muscles receive innervation from the vagus nerve?
# Which of the following muscles is controlled by the vagus nerve?
# The levator veli palatine (levator palatini)
# prediction ISSSSS The levator veli palatine (levator palatini)
# Generated queries:
# Which foramen is most posteriorly present in the base of skull?
# Location of Foramen spinosum in base of skull
# Comparison of Foramen rotundum, Foramen ovale, and Foramen spinosum in base of skull
# Correct choice: Foramen spinosum
# prediction ISSSSS Foramen ovale
# Generated queries:
# Nucleus ambiguus
# prediction ISSSSS Nucleus ambiguus
# Generated queries:
# Central
# prediction ISSSSS Marginal
# Generated queries:
# Coronoid process
# Condylar process
# Upper half of ramus above the level of mandibular foramen
# prediction ISSSSS All of the above
# Generated queries:
# Maxillary and lateral nasal process.
# Lateral nasal and median nasal process.
# Maxillary, lateral nasal, median nasal process.
# prediction ISSSSS Maxillary and lateral nasal process.
# Generated queries:
# Masseter
# Temporalis
# Medial pterygoid
# prediction ISSSSS Lateral pterygoid
# Generated queries:
# Genioglossus
# Mylohyoid
# Digastric
# prediction ISSSSS Mylohyoid
# Generated queries:
# - Hypoglossal nerve
# - Lingual artery
# - Stylohyoid muscle
# prediction ISSSSS Stylohyoid muscle
# Generated queries:
# - Causes of injury to the right mandibular nerve
# - Treatment options for injury to the right mandibular nerve
# - Recovery time for injury to the right mandibular nerve
# prediction ISSSSS Loss of taste from the anterior 2/3 of tongue
# Generated queries:
# Cranial nerve damage when uvula drawn upwards to the left
# Which cranial nerve is affected when uvula drawn upwards to the left
# Symptoms of cranial nerve damage when uvula drawn upwards to the left
# Correct choice: Vagus
# prediction ISSSSS Vagus
# Generated queries:
# Medial to lateral pterygoid
# From Infratemporal fossa
# Lateral to medial pterygoid
# prediction ISSSSS Lateral to medial pterygoid
# Generated queries:
# Scaphoid wrist joint formation
# Ulna wrist joint formation
# Radius wrist joint formation
# prediction ISSSSS Triquetral
# Generated queries:
# One sensory and all motor branches
# prediction ISSSSS One sensory and all motor branches
# Generated queries:
# Anterior 2/3 of tongue
# Posterior 1/3 of tongue
# Anterior 1/3 of tongue
# prediction ISSSSS Anterior 2/3 of tongue
# Generated queries:
# Lateral pterygoid plate
# Maxillary posterior wall
# Pterygomaxillary fissure
# prediction ISSSSS Pterygomaxillary fissure
# Generated queries:
# Dynamic
# prediction ISSSSS Tension of muscle
# Generated queries:
# L1, L2
# prediction ISSSSS L1, L2
# Generated queries:
# Thoracic esophagus drains into the azygos vein
# Esophageal veins drain into a submucosal plexus
# Lower esophageal veins anastomose with the left gastric vein
# prediction ISSSSS The cervical esophagus drains directly into the right brachiocephalic vein
# Generated queries:
# Ectoderm and mesoderm from epiblast; endoderm from hypoblast
# prediction ISSSSS Ectoderm and mesoderm from epiblast; endoderm from hypoblast
# Generated queries:
# 1st arch cartilage.
# 2nd arch cartilage.
# 3rd arch cartilage.
# prediction ISSSSS 2nd arch cartilage.
# Generated queries:
# 6th
# prediction ISSSSS 7th
# Generated queries:
# Which of the following is developed from the 1st arch: Stylohyoid ligament.
# Which of the following is developed from the 1st arch: Spenomandibular ligament.
# Which of the following is developed from the 1st arch: Stapes.
# prediction ISSSSS Stapes.
# Generated queries:
# True about occulomotor nerve are all except carries parasympathetic fibres
# True about occulomotor nerve are all except causes constriction of pupils
# True about occulomotor nerve are all except supplies inferior oblique muscle
# prediction ISSSSS Supplies inferior oblique muscle
# Generated queries:
# Medial Pterygoid
# Lateral pterygoid
# Masseter
# prediction ISSSSS Medial Pterygoid
# Generated queries:
# Platycephaly.
# Microcephaly.
# Anencephaly.
# prediction ISSSSS Brachcephaly.
# Generated queries:
# True statements about osteoblasts are all except:
# - Have a plasma membrane showing multiple folds
# prediction ISSSSS Have neuropeptide receptors
# Generated queries:
# Thyrocervical trunk
# ICA
# Costocervical trunk
# prediction ISSSSS Thyrocervical trunk
# Generated queries:
# Maxillary division of the trigeminal nerve sensory function
# Facial nerve sensory function
# Glossopharyngeal nerve sensory function
# prediction ISSSSS Hypoglossal nerve
# Generated queries:
# Mandibular nerve
# Maxillary nerve
# Lesser occipital nerve
# prediction ISSSSS Mandibular nerve
# Generated queries:
# Lucidum
# prediction ISSSSS Papillary dermis
# Generated queries:
# Occulomotor nerve in cavernous sinus
# Ophthalmic nerve in cavernous sinus
# Maxillary nerve in cavernous sinus
# prediction ISSSSS Optic chiasma
# Generated queries:
# Anterior
# Lateral
# Deep posterior
# prediction ISSSSS Deep posterior
# Generated queries:
# Brachcephaly with narrow foramen magnum is seen in Down syndrome.
# Brachcephaly with narrow foramen magnum is seen in Fanconi syndrome.
# Brachcephaly with narrow foramen magnum is seen in Achondroplasia.
# prediction ISSSSS Cleidocranial dysplasia.
# Generated queries:
# Little finger dorsal interossei
# Ring finger dorsal interossei
# Middle finger dorsal interossei
# prediction ISSSSS Ring
# Generated queries:
# Facial nerve innervates all of the following except Platysma
# Facial nerve innervates all of the following except Anterior belly of digastric
# Facial nerve innervates all of the following except Stapedius
# prediction ISSSSS Anterior belly of digastric
# Generated queries:
# T12
# prediction ISSSSS L1
# Generated queries:
# Ascending pharyngeal
# Superior pharyngeal
# Maxillary
# prediction ISSSSS Maxillary
# Generated queries:
# - Scaphoid wrist joint formation
# - Ulna wrist joint formation
# - Radius wrist joint formation
# Correct choice: Triquetral
# prediction ISSSSS Triquetral
# Generated queries:
# Mesodermal basis of lateral part of lip is formed by Frontonasal process.
# Mesodermal basis of lateral part of lip is formed by Maxillary process.
# Mesodermal basis of lateral part of lip is formed by Globular process.
# prediction ISSSSS Maxillary process.
# Generated queries:
# Infraorbital nerve
# Supraorbital nerve
# Infratrochlear nerve
# Generated queries:
# Infraorbital nerve
# Supraorbital nerve
# Infratrochlear nerve
# prediction ISSSSS Nasociliary nerve
# Generated queries:
# Azygous vein
# Hemiazygous vein
# Internal thoracic vein
# prediction ISSSSS Azygous vein
# Generated queries:
# Brachycephaly
# Oxycephaly
# Trigonocephaly
# prediction ISSSSS Brachycephaly
# Generated queries:
# Synostosis.
# Dysostosis.
# Both
# prediction ISSSSS None
# Generated queries:
# Phrenic nerve in posterior triangle of neck
# Subclavian nerve in posterior triangle of neck
# External jugular vein in posterior triangle of neck
# prediction ISSSSS Hypoglossal nerve
# Generated queries:
# Posterior nasal spine
# Mylohyoid line
# Pterygoid hamulus
# prediction ISSSSS Pterygoid hamulus
# Generated queries:
# RE site
# LoxP site
# NT site
# prediction ISSSSS LoxP site
# Generated queries:
# What pierces the Buccinator: Labial branch of facial nerve
# What does not pierce the Buccinator: Buccal branch of mandibular nerve
# What does not pierce the Buccinator: Parotid duct
# prediction ISSSSS Molar mucous glands
# Generated queries:
# Broca's area is related to Reading
# Broca's area is related to Sentence formation
# Broca's area is related to Word formation
# prediction ISSSSS Sentence formation
# Generated queries:
# Pain carried by dorsal column
# Proprioception carried by dorsal column
# Vibration carried by dorsal column
# prediction ISSSSS Pain
# Generated queries:
# 3 arteries & 1 vein
# prediction ISSSSS 2 arteries & 1 vein
# Generated queries:
# 1st branchial cleft.
# 2nd branchial cleft.
# 2nd branchial arch.
# prediction ISSSSS 1st branchial cleft.
# Generated queries:
# Anterior interosseous
# Posterior interosseous
# Median
# prediction ISSSSS Median
# Generated queries:
# Foramen ovale
# prediction ISSSSS Foramen ovale
# Generated queries:
# House Brackman grading scale used for evaluation of which nerve? Facial nerve
# House Brackman grading scale used for evaluation of which nerve? Hypoglossal
# House Brackman grading scale used for evaluation of which nerve? Vagus
# prediction ISSSSS Facial nerve
# Generated queries:
# Incus and malleus are derived from:
# Dorsal end of meckels cartilage.
# Ventral end of meckels cartilage.
# Inferior end of meckels cartilage.
# prediction ISSSSS Dorsal end of meckels cartilage.
# Generated queries:
# Supranuclear
# Apical
# Adjacent to nucleus
# prediction ISSSSS Supranuclear
# Generated queries:
# Nociceptive signals are transmitted primarily to Nucleus caudalis
# Nociceptive signals are transmitted primarily to Limbic system
# Nociceptive signals are transmitted primarily to Reticular system
# prediction ISSSSS Limbic system
# Generated queries:
# Auriculotemporal nerve
# Facial nerve
# Masseteric nerve
# prediction ISSSSS Auriculotemporal nerve
# Generated queries:
# A
# B
# C
# prediction ISSSSS A
# Generated queries:
# Eyes
# Ears
# Brain
# Generated queries:
# Face
# prediction ISSSSS Face
# Generated queries:
# Greater petrosal nerve
# Lesser petrosal nerve
# Chorda tympani
# prediction ISSSSS Lesser petrosal nerve
# Generated queries:
# Exocrine and merocrine
# prediction ISSSSS Exocrine and merocrine
# Generated queries:
# Tensor veli palatini is supplied by:
# Facial nerve
# Trigeminal nerve
# Glossopharyngeal nerve
# prediction ISSSSS Trigeminal nerve
# Generated queries:
# Tensor tympani derived from pharyngeal arches
# Levator palpebrae superioris derived from pharyngeal arches
# Orbicularis oculi derived from pharyngeal arches
# Correct choice: Palatine tensor
# prediction ISSSSS Levator palpebrae superioris
# Generated queries:
# What artery does the auriculotemporal nerve encircle?
# Superficial temporal artery
# Superficial temporal vein
# Middle meningeal artery
# Deep temporal
# prediction ISSSSS Superficial temporal artery
# Generated queries:
# Ligamentum flavum Type-II collagen
# Ligamentum flavum Type-III collagen
# Ligamentum flavum Elastin
# prediction ISSSSS Type-II collagen
# Generated queries:
# Position of adenoid is in the Nasopharynx
# Position of adenoid is in the Nasopharynx
# Position of adenoid is in the Nasopharynx
# prediction ISSSSS Nasopharynx
# Generated queries:
# Passavant's ridge
# Sulcus terminalis
# Circumvallate papillae
# prediction ISSSSS Sulcus terminalis
# Generated queries:
# Frontonasal process.
# 2 palatal process.
# Maxillary process.
# prediction ISSSSS All of the above.
# Generated queries:
# Sphenopalatine artery
# greater palatine artery
# superior labial artery
# prediction ISSSSS anterior ethmoidal
# Generated queries:
# Common carotid artery divides to ICA & ECA at:
# Thyroid cartilage
# prediction ISSSSS Thyroid cartilage
# Generated queries:
# Which of the following is unpaired bone of facial skeleton: Nasal
# Which of the following is unpaired bone of facial skeleton: Lacrimal
# Which of the following is unpaired bone of facial skeleton: Inferior nasal concha
# Correct choice: Vomer
# prediction ISSSSS Vomer
# Generated queries:
# Superior laryngeal
# prediction ISSSSS Superior laryngeal
# Generated queries:
# Supraspinatus
# lnfraspinatus
# Teres minor
# prediction ISSSSS Subscapularis
# Generated queries:
# Buccinator muscle
# Superior constrictor
# Masseter
# prediction ISSSSS Buccinator muscle
# Generated queries:
# Contralateral lateral pterygoid
# Ispilateral lateral pterygoid
# Same side medial pterygoid
# prediction ISSSSS Ispilateral lateral pterygoid
# Generated queries:
# All intrinsic muscles are supplied by the recurrent laryngeal nerve
# Cricothyroid is supplied by the external laryngeal nerve
# Posterior cricoarytenoid abduct the vocal cords
# prediction ISSSSS Cricothyroid is supplied by the external laryngeal nerve
# Generated queries:
# - Lingual nerve mandible relation
# - Auriculotemporal nerve mandible relation
# - Chorda tympani mandible relation
# prediction ISSSSS Auriculotemporal nerve
# Generated queries:
# Bile Duct
# Hepatic Vein
# Hepatic aery
# prediction ISSSSS Bile Duct
# Generated queries:
# Which cranial nerve is associated with olfaction?
# Cranial nerve XII olfaction association
# Cranial nerve IX olfaction association
# prediction ISSSSS IX
# Generated queries:
# Levator Ani function
# Levator Ani anatomy
# Levator Ani attachments
# prediction ISSSSS Converge downwards & medially
# Generated queries:
# Skin
# Thoracic fascia
# Pulmonary pleura
# prediction ISSSSS Pulmonary pleura
# Generated queries:
# Purkinje fibers project to caudate nucleus
# Purkinje fibers project to red nucleus
# Purkinje fibers project to dentate nucleus
# prediction ISSSSS Red nucleus
# Generated queries:
# Infratemporal artery
# Deep temporal artery
# Maxillary artery
# prediction ISSSSS Maxillary artery
# Generated queries:
# Infarction of anterior inferior cerebellar artery may cause damage to Pyramidal tract
# Infarction of anterior inferior cerebellar artery may cause damage to Lateral spinothalamic tract
# Infarction of anterior inferior cerebellar artery may cause damage to Vestibular nuclei
# prediction ISSSSS Vestibular nuclei
# Generated queries:
# Pharyngeal arches are rod like thickening of: Endoderm.
# Pharyngeal arches are rod like thickening of: Ectoderm.
# Pharyngeal arches are rod like thickening of: Mesoderm.
# prediction ISSSSS Mesoderm.
# Generated queries:
# What is the arterial supply to the floor of mouth and suprahyoid muscle?
# What arteries supply the floor of mouth and suprahyoid muscle?
# Anatomy of lingual artery, maxillary artery, inferior alveolar artery, and facial artery in relation to the floor of mouth and suprahyoid muscle.
# prediction ISSSSS Facial artery
# Generated queries:
# Rounded bulge produced by first turn of cochlea
# Oval opening posterosuperior to the promontory
# Prominence produced due to the lateral semicircular canal
# prediction ISSSSS Oval opening posterosuperior to the promontory
# Generated queries:
# Release of catecholamines is not affected by nerve supply to adrenals
# Preganglionic fibres from lower thoracic and lumbar veebra come sympathetic chain to supply adrenals
# Adrenal coex doesn't have nerve supply as it has endocrine functions
# prediction ISSSSS Preganglionic fibres from lower thoracic and lumbar veebra come sympathetic chain to supply adrenals
# Generated queries:
# Palatine process begins to fuse at 8th week of fertilization
# Palatine process begins to fuse at 10th week of fertilization
# Palatine process begins to fuse at 12th week of fertilization
# prediction ISSSSS 8th week of fertilization
# Generated queries:
# Glossopharyngeal nerve
# Lingual nerve
# Hypoglossal
# prediction ISSSSS Lingual nerve
# Generated queries:
# Lesion of the marked structure affects all EXCEPT Superior rectus
# Lesion of the marked structure affects all EXCEPT Superior oblique
# Lesion of the marked structure affects all EXCEPT Medial rectus
# prediction ISSSSS Inferior oblique
# Generated queries:
# Which of the following projects efferent fibers through the marked structure: Hippocampus
# Which of the following projects efferent fibers through the marked structure: Mammillary body
# Which of the following projects efferent fibers through the marked structure: Caudate nucleus
# prediction ISSSSS Mammillary body
# Generated queries:
# Passavant’s ridge is located on which of the following:
# Posterior wall of oropharynx
# Passavant’s ridge is located on which of the following:
# Anterior wall of oropharynx
# Passavant’s ridge is located on which of the following:
# Posterior wall of nasopharynx
# prediction ISSSSS Posterior wall of oropharynx
# Generated queries:
# - Cartilage of larynx are developed from 4th arch cartilage.
# - Cartilage of larynx are developed from 4&5 arch cartilage.
# - Cartilage of larynx are developed from 4&6 arch cartilage.
# prediction ISSSSS 3rd arch cartilage.
# Generated queries:
# Greater auricular nerve
# Lesser occipital nerve
# Auriculotemporal nerve
# prediction ISSSSS Greater auricular nerve
# Generated queries:
# - Does the typical cervical vertebra have a triangular body?
# - Does the typical cervical vertebra have a foramen transversarium?
# - Is the superior articular facet of the typical cervical vertebra directed backwards and upwards?
# prediction ISSSSS Has a foramen transversarium
# Generated queries:
# Lamina cribrosa is a modification of Sclera
# Lamina cribrosa is a modification of Choroid
# Lamina cribrosa is a modification of Optic nerve sheath
# prediction ISSSSS Sclera
# Generated queries:
# Card test Palmar interossei
# Card test Dorsal interossei
# Card test Lumbricals
# Card test Adductor pollicis
# prediction ISSSSS Palmar interossei
# Generated queries:
# Spermatogonia to primary spermatocyte
# Primary spermatocyte to secondary spermatocyte
# Secondary spermatocyte to spermatids
# prediction ISSSSS Primary spermatocyte to secondary spermatocyte
# Generated queries:
# Levator ani muscle attachments
# Levator ani muscle components
# Levator ani muscle fiber direction
# prediction ISSSSS Levator ani muscle is attached at pelvic brim
# Generated queries:
# Ethmoid
# prediction ISSSSS Sphenoid
# Generated queries:
# - Grey communicans myelinated
# - Grey communicans does not connect to spinal nerves
# - Grey communicans postganglionic
# prediction ISSSSS Present medial to the white ramus cornmunicans
# Generated queries:
# - Sarorius muscle fiber orientation
# - Rectus abdominis muscle fiber orientation
# - Sternohyoid muscle fiber orientation
# Correct choice: Tibialis anterior
# prediction ISSSSS Saorius
# Generated queries:
# Triangular
# Quadrilateral
# Trapezium
# prediction ISSSSS Quadrilateral
# Generated queries:
# Endodermal origin of epithelial cells
# Endodermal origin of odontoblasts
# Endodermal origin of goblet cells
# Endodermal origin of hepatocytes
# Correct choice: Odontoblasts
# prediction ISSSSS Odontoblasts
# Generated queries:
# Nasociliary nerve
# Greater petrosal nerve
# Trigeminal nerve
# prediction ISSSSS Greater petrosal nerve
# Generated queries:
# Suture.
# Gomphosis.
# Synchondrosis.
# prediction ISSSSS Syndesmosis.
# Generated queries:
# Portal vein
# Hepatic vein
# Bile duct
# prediction ISSSSS Bile duct
# Generated queries:
# Inferior rectal vein content mesorectal fascia
# Superior rectal vein content mesorectal fascia
# Pararectal lymph node content mesorectal fascia
# prediction ISSSSS Inferior mesenteric plexus
# Generated queries:
# Right and left CCA.
# Right and left subclavian artery and arch of aorta.
# Right and left pulmonary arteries.
# prediction ISSSSS Right and left CCA.
# Generated queries:
# Ectoderm.
# Endoderm.
# Both AB.
# prediction ISSSSS Ectoderm.
# Generated queries:
# Ethmoid bone
# Tongue
# Sphenoid
# prediction ISSSSS Ethmoid bone
# Generated queries:
# Zona occludens cell junctions
# Zona adherens cell junctions
# Macula adherens cell junctions
# prediction ISSSSS Macula adherens
# Generated queries:
# Skull of newborn diploe formation
# Skull of newborn styloid process fusion
# Skull of newborn anterior fontanelle closure
# Skull of newborn mastoid process size
# prediction ISSSSS Mastoid process is of adult size
# Generated queries:
# Basilar artery structures in the brain
# Vertebral artery structures in the brain
# Middle cerebral artery structures in the brain
# prediction ISSSSS Basilar artery
# Generated queries:
# Occulomotor nerve
# prediction ISSSSS Occulomotor nerve
# Generated queries:
# What does the auriculotemporal nerve encircle around the Superficial temporal vein
# What does the auriculotemporal nerve encircle around the Superficial temporal artery
# What does the auriculotemporal nerve encircle around the Middle meningeal artery
# prediction ISSSSS Superficial temporal artery
# Generated queries:
# Medial squint is caused by paralysis of Occulomotor nerve
# Medial squint is caused by paralysis of Abducens nerve
# Medial squint is caused by paralysis of Trochlear nerve
# prediction ISSSSS Trochlear nerve
# Generated queries:
# Between roots of premolars
# Between roots of molars
# Near canine
# Generated queries:
# Between roots of premolars
# prediction ISSSSS Between premolars
# Generated queries:
# Spinocerebellar tract
# Dorsal column tract
# Vestibulospinal tract
# prediction ISSSSS Spinocerebellar tract
# Generated queries:
# Cranioveebral joint does not include occipital condyle
# Cranioveebral joint does not include axis
# Cranioveebral joint does not include atlas
# prediction ISSSSS Wings of sphenoid
# Generated queries:
# - What is the deepest layer of cervical fascia: Vertebral
# - Identify the deepest layer of cervical fascia: Carotid sheath
# - Which layer is the deepest in cervical fascia: Prevertebral fascia
# prediction ISSSSS Prevertebral fascia
# Generated queries:
# Nasal cavity and anterior cranial fossa
# Nasal cavity and orbit
# Nasal cavity and oral cavity
# prediction ISSSSS Nasal cavity and anterior cranial fossa
# Generated queries:
# Mandibular fossa is a part of: Mandible bone
# Mandibular fossa is a part of: Temporal bone
# Mandibular fossa is a part of: Sphenoid bone
# prediction ISSSSS Temporal bone
# Generated queries:
# Preganglionic parasympathetic fibres travel to otic ganglion from: Facial nerve
# Preganglionic parasympathetic fibres travel to otic ganglion from: Glossopharyngeal nerve
# Preganglionic parasympathetic fibres travel to otic ganglion from: Trigeminal nerve
# prediction ISSSSS Glossopharyngeal nerve
# Generated queries:
# Inferior thyroid artery is a branch of Internal thoracic artery
# Inferior thyroid artery is a branch of Thyrocervical trunk
# Inferior thyroid artery is a branch of Costocervical trunk
# prediction ISSSSS Thyrocervical trunk
# Generated queries:
# Posterior auricular artery
# Occipital artery
# Maxillary artery
# prediction ISSSSS Ophthalmic artery
# Generated queries:
# Recurrent Laryngeal nerve
# Superior laryngeal nerve
# Vagus nerve
# prediction ISSSSS Vagus nerve
# Generated queries:
# Submental nodes
# Sublingual nodes
# Preauricular nodes
# prediction ISSSSS Submental nodes
# Generated queries:
# Inferior oblique muscle of the eye downward rotation
# Inferior oblique muscle of the eye lateral rotation
# Inferior oblique muscle of the eye extortion
# prediction ISSSSS Lateral rotation
# Generated queries:
# Cords of billroth
# Hassall's corpuscles
# Lymphatic nodules
# prediction ISSSSS Lymphatic nodules
# Generated queries:
# Origin Greater wing of sphenoid and scaphoid fossa; Insertion as palatine aponeurosis into posterior hard palate.
# Origin Lesser wing of sphenoid and scaphoid fossa;Insertion Hamular notch and opposite muscle of same name
# Origin Lesser wing of sphenoid and scaphoid fossa; Insertion- Posterior hard palate
# prediction ISSSSS Origin Lesser wing of sphenoid and scaphoid fossa; Insertion: as palatine aponeurosis into posterior hard palate.
# Generated queries:
# Inferior wall of orbit bones
# Ethmoid bone function
# Maxillary bone anatomy
# prediction ISSSSS Ethmoid
# Generated queries:
# Injury to deep branch of ulnar nerve
# Injury to median nerve
# Injury to radial nerve
# prediction ISSSSS Deep branch of ulnar nerve
# Generated queries:
# Which muscles are attached laterally to thyroid cartilage?
# Which muscles are attached to the oblique line of thyroid cartilage?
# Which muscles are not attached laterally to thyroid cartilage?
# Correct choice: Superior constrictor
# prediction ISSSSS Superior constrictor
# Generated queries:
# Genial tubercle presence on internal surface of mandible
# Mylohyoid ridge presence on internal surface of mandible
# Lingula presence on internal surface of mandible
# prediction ISSSSS Mental foramen
# Generated queries:
# Roots of trigeminal nerve attachment to Pons
# Trigeminal nerve main divisions
# Trigeminal nerve supply dura mater middle cranial fossa
# prediction ISSSSS The trigeminal ganglion contributes to the sensory root only
# Generated queries:
# Inferior to mylohyoid
# prediction ISSSSS Inferior to mylohyoid
# Generated queries:
# Lower border of L1
# L2
# L3
# prediction ISSSSS Lower border of L1
# Generated queries:
# What does the foramen magnum transmit besides the vertebral artery?
# What passes through the foramen magnum besides the spinal branch of the 10th nerve?
# What structures are transmitted through the foramen magnum, excluding both option 2 and 3?
# Correct choice: Both option 2 and 3
# prediction ISSSSS Both option 2 and 3
# Generated queries:
# Sinus of morgagni
# Between thyropharyngeal and cricopharyngeal sphincter
# Piriform fossa
# prediction ISSSSS Between thyropharyngeal and cricopharyngeal sphincter
# Generated queries:
# Example of synarthroses is suture
# Example of synarthroses is syndesmosis
# Example of synarthroses is gomphosis
# prediction ISSSSS All of the above.
# Generated queries:
# Asseion is true but reason is false
# prediction ISSSSS Asseion is true but reason is false
# Generated queries:
# A. ii) B. ii) C. i) D. i) E. i)
# A. i) B. ii) C. ii) D. i) E. i)
# A. i) B. ii) C. i) D. i) E. ii)
# prediction ISSSSS A. i) B. ii) C. i) D. i) E. ii)
# Generated queries:
# Middle meningeal artery
# Meningeal branch of internal carotid artery in posterior cranial fossa
# Anterior and posterior ethmoidal arteries
# prediction ISSSSS Anterior and posterior ethmoidal aeries
# Generated queries:
# Scoliosis
# Lordosis
# Kyphosis
# prediction ISSSSS Lordosis
# Generated queries:
# Oxycephaly.
# Turticephaly.
# Dome shaped skull.
# prediction ISSSSS Oxycephaly.
# Generated queries:
# Supraspinatus function in shoulder joint
# Infraspinatus role in rotator cuff muscles
# Teres minor importance in shoulder biomechanics
# prediction ISSSSS Subscapularis
# Generated queries:
# Pharyngotympanic tube blood supply
# Ascending pharyngeal artery supply
# Middle meningeal artery function
# prediction ISSSSS Middle meningeal artery
# Generated queries:
# Stylopharyngeus function
# Palatopharyngeus innervation
# Geniohyoid nerve supply
# prediction ISSSSS Stylopharyngeus
# Generated queries:
# 7th cranial nerve, third cervical nerve and first thoracic nerve
# prediction ISSSSS 5th cranial nerve, third cervical nerve and first thoracic nerve
# Generated queries:
# What is agenesis of an organ?
# What is aplasia of an organ?
# What is atresia of an organ?
# prediction ISSSSS Aplasia
# Generated queries:
# Nasal cavity and anterior cranial fossa
# Nasal cavity and orbit
# Nasal cavity and oral cavity
# prediction ISSSSS Nasal cavity and anterior cranial fossa
# Generated queries:
# Middle constrictor of pharynx attachment from body of hyoid bone
# Middle constrictor of pharynx attachment from mandible
# Middle constrictor of pharynx attachment from pterygomandibular raphae
# Generated queries:
# Body of hyoid bone
# Mandible
# Pterygomandibular raphae
# prediction ISSSSS Stylohyoid ligament and horns of hyoid bone
# Generated queries:
# Auriculotemporal nerve
# Facial nerve
# Massetric nerve
# prediction ISSSSS Auriculotemporal nerve
# Generated queries:
# Facial
# prediction ISSSSS Auriculotemporal
# Generated queries:
# Sella tursica lies above Pons
# Sella tursica lies above Frontal sinus
# Sella tursica lies above Foramen ovale
# prediction ISSSSS Sphenoidal sinus
# Generated queries:
# Petrous temporal bone
# Crista galli
# Transverse groove
# prediction ISSSSS Petrous temporal bone
# Generated queries:
# Corneocytes>merkel cell>melanocytes>langerhans cells
# prediction ISSSSS Corneocytes>merkel cell>melanocytes>langerhans cells
# Generated queries:
# The middle meningeal artery is associated with which foramen: Ovale
# The middle meningeal artery is associated with which foramen: Rotundum
# The middle meningeal artery is associated with which foramen: Spinosum
# prediction ISSSSS Rotundum
# Generated queries:
# Plagiocephaly.
# Anencephaly.
# Scaphocephaly.
# prediction ISSSSS Scaphocephaly.
# Generated queries:
# Dorsal part of 2nd pouch give rise to:
# Tonsils.
# Thymus.
# Tubotympanic recess.
# prediction ISSSSS Tonsils.
# Generated queries:
# Palatoglossus and palatopharyngeus
# Uvula
# Mucous membrane and muscles
# prediction ISSSSS All of the above
# Generated queries:
# Grey rami communicantes connected to spinal nerve
# Grey rami communicantes present medial to white rami communicantes
# Grey rami communicantes carries pre-ganglionic fibres
# prediction ISSSSS Present medial to white rami communicantes
# Generated queries:
# Scoliosis
# prediction ISSSSS Lordosis
# Generated queries:
# Sphenoidal
# prediction ISSSSS Sphenoidal
# Generated queries:
# Lower two parts of sternal body is fused by 8 years
# prediction ISSSSS 14 years
# Generated queries:
# IX cranial nerve
# X cranial nerve
# VII cranial nerve
# prediction ISSSSS IX cranial nerve
# Generated queries:
# Inferior turbinate
# prediction ISSSSS Crista galli
# Generated queries:
# Syndesmosis
# Synchondrosis
# Suture
# prediction ISSSSS Syndesmosis
# Generated queries:
# Amphiarthroses.
# Diarthroses.
# Synarthroses.
# prediction ISSSSS Diarthroses.
# Generated queries:
# Extra-embryonic mesoderm is derived from: Epiblast
# Extra-embryonic mesoderm is derived from: Primary yolk sac
# Extra-embryonic mesoderm is derived from: Hypoblast
# prediction ISSSSS Hypoblast
# Generated queries:
# Little
# prediction ISSSSS Ring
# Generated queries:
# Palatoglossus develops from:
# Lingual swelling of first arch
# prediction ISSSSS Lingual swelling of first arch
# Generated queries:
# Inca bone or Goethe's ossicles is a sutural bone present in Bregma
# Inca bone or Goethe's ossicles is a sutural bone present in Lambda
# Inca bone or Goethe's ossicles is a sutural bone present in Pterion
# prediction ISSSSS Lambda
# Generated queries:
# Paroophoron function
# Vas deferens anatomy
# Epididymis development
# Correct choice: Glomerulus
# prediction ISSSSS Glomerulus
# Generated queries:
# Tendon of Gracilis, Sartorius and semitendenous muscles insert on tibia to form Pesanserinus. Similar structure is seen in
# TMJ
# prediction ISSSSS TMJ
# Generated queries:
# Ligamentum flavum Type-I collagen fibers
# Ligamentum flavum Type-II collagen fibers
# Ligamentum flavum Elastic fibers
# prediction ISSSSS Elastic
# Generated queries:
# 10 weeks post fertilisation
# prediction ISSSSS 8 weeks post fertilisation
# Generated queries:
# Efferent tracts from cerebellum arises from Purkinje cells
# Efferent tracts from cerebellum arises from Deep cerebellar nuclei
# Efferent tracts from cerebellum arises from Cerebellar cortex
# prediction ISSSSS Deep cerebellar nuclei
# Generated queries:
# Touch
# Pain
# Temperature
# prediction ISSSSS Proprioception
# Generated queries:
# Dense irregular connective tissue is found in Dermis
# Dense irregular connective tissue is found in Lamina propria
# Dense irregular connective tissue is found in Tendon
# prediction ISSSSS Dermis
# Generated queries:
# Muscles spared by complete transection of cranial part of accessory nerve: Cricopharyngeus
# Muscles spared by complete transection of cranial part of accessory nerve: Palatopharyngeus
# Muscles spared by complete transection of cranial part of accessory nerve: Stylopharyngeus
# prediction ISSSSS Cricopharyngeus
# Generated queries:
# Is a point of articulation of four skull bones
# It is a point where 'bregma' and 'lamba' meet
# It is region of the postero-lateral fontanelle merge
# Generated queries:
# What bones articulate at the pterion?
# Where do the 'bregma' and 'lamba' meet?
# What is the region where the postero-lateral fontanelle merge?
# prediction ISSSSS Is a point of articulation of four skull bones
# Generated queries:
# Symphyses.
# Synchondrosis.
# Syndesmosis.
# prediction ISSSSS Synchondrosis.
# Generated queries:
# Epidural venous plexus is located in Basal ganglia adjacent to pons
# Epidural venous plexus is located in At the junction of middle and posterior cranial fossa
# Epidural venous plexus is located in In vertebral canal below duramater
# prediction ISSSSS In vertebral canal below duramater
# Generated queries:
# Superior thyroid artery
# Transverse cervical artery
# Ascending pharyngeal artery
# prediction ISSSSS Transverse cervical aery
# Generated queries:
# Second part of maxillary artery
# Third part of maxillary artery
# First part of maxillary artery
# prediction ISSSSS Second part of maxillary artery
# Generated queries:
# Facial nerve
# Mandibular nerve
# Maxillary nerve
# prediction ISSSSS Facial nerve
# Generated queries:
# Palatoglossus arch
# Facial musculature
# Lips
# prediction ISSSSS Palatoglossus arch
# Generated queries:
# Buccinator function
# Masseter function
# Temporalis function
# Pterygoids function
# Correct choice: Buccinator
# prediction ISSSSS Buccinator
# Generated queries:
# Type I collagen is present in all EXCEPT Ligament
# Type I collagen is present in all EXCEPT Aponeurosis
# Type I collagen is present in all EXCEPT Cailage
# prediction ISSSSS Cailage
# Generated queries:
# Mesentery of sigmoid colon relation to left ureter
# Bifurcation of common iliac artery relation to left ureter
# Quadratus lumborum relation to left ureter
# Correct choice: Gonadal vessels
# prediction ISSSSS Mesentery of sigmoid colon
# Generated queries:
# Commissure of Ganser
# prediction ISSSSS Corpus callosum
# Generated queries:
# Preganglionic fibres from lower thoracic & upper lumbar spinal segments sympathetic chain
# Adrenal coex has no nerve supply
# Adrenal medulla has no nerve supply
# prediction ISSSSS Preganglionic fibres from lower thoracic & upper lumbar spinal segments sympathetic chain
# Generated queries:
# Plane diarthroses joint
# Symphyses diarthroses joint
# Condyloid diarthroses joint
# Correct choice: Saddle.
# prediction ISSSSS Symphyses.
# Generated queries:
# Gallbladder
# Duodenum
# Collecting duct
# prediction ISSSSS Gallbladder
# Generated queries:
# Deepest layer of deep cervical fascia is Prevertebral
# Deepest layer of deep cervical fascia is Carotid sheath
# Deepest layer of deep cervical fascia is Pretracheal
# prediction ISSSSS Prevertebral
# Generated queries:
# Phrenic nerve chiefly supplies Diaphragm
# prediction ISSSSS Diaphragm
# Generated queries:
# Occulomotor nerve passes through Superior orbital fissure
# Occulomotor nerve passes through Inferior orbital fissure
# Occulomotor nerve passes through Foramen ovale
# prediction ISSSSS Superior orbital fissure
# Generated queries:
# Masseter
# Buccinator
# Middle temporal
# prediction ISSSSS Masseter
# Generated queries:
# Facial nerve
# Trigeminal nerve
# Glossopharyngeal nerve
# prediction ISSSSS Facial nerve
# Generated queries:
# Tongue develops from all of the following except Tuberculum impar
# Tongue develops from all of the following except Hypobranchial eminence
# Tongue develops from all of the following except Lingual swellings
# prediction ISSSSS Arytenoid swellings
# Generated queries:
# Which artery supplies the circle of Willis?
# Which arteries supply the circle of Willis?
# What arteries make up the circle of Willis?
# prediction ISSSSS Posterior-inferior cerebral
# Generated queries:
# Extensor hallucis longus inversion of foot
# Tibialis anterior inversion of foot
# Peroneus longus inversion of foot
# prediction ISSSSS Peroneus longus
# Generated queries:
# Postganglionic parasympathetic fibre secretomotor
# Preganglionic parasympathetic fibre relay in Otic ganglion
# Preganglionic parasympathetic nerve begin in inferior petrosal nucleus
# prediction ISSSSS Preganglionic parasympathetic nerve begin in inferior petrosal nucleus
# Generated queries:
# Digastric
# Masseter
# Medial pterygoid
# prediction ISSSSS Digastric
# Generated queries:
# Superior rectal artery
# Middle rectal artery
# Inferior rectal artery
# Generated queries:
# Superior rectal aery
# prediction ISSSSS Inferior rectal artery
# Generated queries:
# Depression of mandible
# Protrusion of mandible
# Side-to-side movement of mandible
# prediction ISSSSS Depression of mandible

# %%
print("exact_match:", exact_match)
print("mismatch:", mismatch)
# score w rerank thing 0.5641025641025641
# Out:
# exact_match: 0.5641025641025641
# mismatch: 0.02564102564102564

# %% [markdown]
# # query engine 3

# %%
def predict3(prompt):
    return str(query_engine3.query(prompt))

def evaluate3():
  SAMPLE_CNT = len(dataset_validation)
  mismatch_cnt = 0
  predictions = []
  references = []

  for i in range(SAMPLE_CNT):
    example = dataset_validation[i]
    question, option_a, option_b, option_c, option_d = example["question"], example["opa"], example["opb"], example["opc"], example["opd"]
    prompt = f'''{question}

{option_a}
{option_b}
{option_c}
{option_d}

Respond with the correct choice from the list above verbatim.  Do not include any explanation.'''

    options = [example['opa'], example['opb'], example['opc'], example['opd']]
    correct_option = options[example['cop']]
    references.append(correct_option)

    prediction = predict3(prompt)
    if prediction not in options:
      prompt += prediction + "\n\nYour response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again\n\n" + example['opa'] + "\n\n" + example['opb'] + "\n\n" + example['opc'] + "\n\n" + example['opd']
      prediction = predict3(prompt)

    predictions.append(prediction)

    mismatch_cnt += prediction not in options

  exact_match = sum([prediction == reference for prediction, reference, in zip(predictions, references)]) / SAMPLE_CNT
  mismatch = mismatch_cnt / SAMPLE_CNT

  return exact_match, mismatch

exact_match, mismatch = evaluate3()

# %%
print("exact_match:", exact_match)
print("mismatch:", mismatch)
# Out:
# exact_match: 0.5726495726495726
# mismatch: 0.02564102564102564

# %% [markdown]
# # query engine 4

# %%
def predict4(prompt):
    return str(query_engine4.query(prompt))

def evaluate4():
  SAMPLE_CNT = len(dataset_validation)
  mismatch_cnt = 0
  predictions = []
  references = []

  for i in range(SAMPLE_CNT):
    example = dataset_validation[i]
    question, option_a, option_b, option_c, option_d = example["question"], example["opa"], example["opb"], example["opc"], example["opd"]
    prompt = f'''{question}

{option_a}
{option_b}
{option_c}
{option_d}

Respond with the correct choice from the list above verbatim.  Do not include any explanation.'''

    options = [example['opa'], example['opb'], example['opc'], example['opd']]
    correct_option = options[example['cop']]
    references.append(correct_option)

    prediction = predict4(prompt)
    if prediction not in options:
      prompt += prediction + "\n\nYour response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again\n\n" + example['opa'] + "\n\n" + example['opb'] + "\n\n" + example['opc'] + "\n\n" + example['opd']
      prediction = predict4(prompt)

    predictions.append(prediction)

    mismatch_cnt += prediction not in options

  exact_match = sum([prediction == reference for prediction, reference, in zip(predictions, references)]) / SAMPLE_CNT
  mismatch = mismatch_cnt / SAMPLE_CNT

  return exact_match, mismatch

exact_match, mismatch = evaluate4()

# %%
print("exact_match:", exact_match)
print("mismatch:", mismatch)
# Out:
# exact_match: 0.5769230769230769
# mismatch: 0.02564102564102564

# %% [markdown]
# # query engine 5

# %%
def predict5(prompt):
    return str(query_engine5.query(prompt))

def evaluate5():
  SAMPLE_CNT = len(dataset_validation)
  mismatch_cnt = 0
  predictions = []
  references = []

  for i in range(SAMPLE_CNT):
    example = dataset_validation[i]
    question, option_a, option_b, option_c, option_d = example["question"], example["opa"], example["opb"], example["opc"], example["opd"]
    prompt = f'''{question}

{option_a}
{option_b}
{option_c}
{option_d}

Respond with the correct choice from the list above verbatim.  Do not include any explanation.'''

    options = [example['opa'], example['opb'], example['opc'], example['opd']]
    correct_option = options[example['cop']]
    references.append(correct_option)

    prediction = predict5(prompt)
    if prediction not in options:
      prompt += prediction + "\n\nYour response does not exactly match one of the choices from the list. Do not apologise or include any text other than one of the options from the list verbatim without any label. Here are the options again\n\n" + example['opa'] + "\n\n" + example['opb'] + "\n\n" + example['opc'] + "\n\n" + example['opd']
      prediction = predict5(prompt)

    predictions.append(prediction)

    mismatch_cnt += prediction not in options

  exact_match = sum([prediction == reference for prediction, reference, in zip(predictions, references)]) / SAMPLE_CNT
  mismatch = mismatch_cnt / SAMPLE_CNT

  return exact_match, mismatch

exact_match, mismatch = evaluate5()

# %%
print("exact_match:", exact_match)
print("mismatch:", mismatch)
# Out:
# exact_match: 0.5726495726495726
# mismatch: 0.017094017094017096
